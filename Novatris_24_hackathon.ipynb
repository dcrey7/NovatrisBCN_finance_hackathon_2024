# %% [markdown]
# # imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import make_scorer
from sklearn import preprocessing
from pathlib import Path
from typing import Tuple
import gower
from sklearn.preprocessing import MinMaxScaler
from scipy.spatial.distance import pdist, squareform
from sklearn.model_selection import GridSearchCV
import lightgbm as lgb

# Set display options
pd.set_option('display.max_columns', 100)
pd.set_option("display.max_rows", 2000)

# Set plot style
plt.style.use('fivethirtyeight')

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %%
train = pd.read_csv('../Data Files/train_data.csv')
cols = ['date', 'drug_id', 'brand', 'country', 'cluster_nl', 'population', 'public_perc_che', 'che_perc_gdp',
'che_pc_usd', 'insurance_perc_che', 'corporation', 'indication', 'launch_date', 'ind_launch_date',
'therapeutic_area', 'prev_perc', 'price_unit', 'price_month', 'target']
train = train[cols]
print(train.shape)
train.head(5)
# Out:
# (118917, 19)
#          date       drug_id       brand       country  \
# 0  2014-06-01  DRUG_ID_8795  BRAND_354E  COUNTRY_88A3
# 1  2014-06-01  DRUG_ID_E66E  BRAND_626D  COUNTRY_8B47
# 2  2014-06-01  DRUG_ID_F272  BRAND_45D9  COUNTRY_88A3
# 3  2014-06-01  DRUG_ID_1D4E  BRAND_D724  COUNTRY_445D
# 4  2014-06-01  DRUG_ID_AA88  BRAND_4887  COUNTRY_D8B0
#
#                 cluster_nl  population  public_perc_che  che_perc_gdp  \
# 0  BRAND_354E_COUNTRY_88A3    1.008039         1.835821      1.665879
# 1  BRAND_626D_COUNTRY_8B47    1.023562        -1.000000     -1.000000
# 2  BRAND_45D9_COUNTRY_88A3    1.008039         1.835821      1.665879
# 3  BRAND_D724_COUNTRY_445D    1.253186         1.805970      2.051770
# 4  BRAND_4887_COUNTRY_D8B0    1.639352         1.880597      2.059130
#
#    che_pc_usd  insurance_perc_che corporation                indication  \
# 0    1.209114            1.893333   CORP_D524              ['IND_C3B6']
# 1   -1.000000           -1.000000   CORP_01C7  ['IND_1590', 'IND_ECAC']
# 2    1.209114            1.893333   CORP_39F7              ['IND_B2EF']
# 3    1.851280            1.000000   CORP_711A              ['IND_BAFB']
# 4    1.791199            2.013333   CORP_443D              ['IND_3F31']
#
#   launch_date      ind_launch_date therapeutic_area  prev_perc  price_unit  \
# 0  2014-06-01                   -1   THER_AREA_980E   0.028367    1.013784
# 1  2014-06-01  2014-09-01 00:00:00   THER_AREA_96D7   0.000047    1.626677
# 2  2014-06-01                   -1   THER_AREA_96D7   0.001502    3.144874
# 3  2014-06-01                   -1   THER_AREA_6CEE   0.001304    1.213446
# 4  2014-06-01                   -1   THER_AREA_6CEE   0.054467    1.008708
#
#    price_month    target
# 0     1.006444  1.000784
# 1    -1.000000  1.000000
# 2    -1.000000  1.002258
# 3    -1.000000  1.068761
# 4     1.018589  1.036312

# %%
test = pd.read_csv('../Data Files/submission_data.csv')
test = test[cols]
print(test.shape)
test.head(5)
# Out:
# (1769, 19)
#          date       drug_id       brand       country  \
# 0  2023-01-01  DRUG_ID_FADD  BRAND_E57A  COUNTRY_06E4
# 1  2023-01-01  DRUG_ID_E07F  BRAND_014B  COUNTRY_06E4
# 2  2023-01-01  DRUG_ID_1A21  BRAND_1E6F  COUNTRY_4647
# 3  2023-01-01  DRUG_ID_1315  BRAND_9259  COUNTRY_FA79
# 4  2023-01-01  DRUG_ID_2832  BRAND_106A  COUNTRY_E319
#
#                 cluster_nl  population  public_perc_che  che_perc_gdp  \
# 0  BRAND_E57A_COUNTRY_06E4    1.004739         1.910448      1.467920
# 1  BRAND_014B_COUNTRY_06E4    1.004739         1.910448      1.467920
# 2  BRAND_1E6F_COUNTRY_4647    3.243906         1.567164      1.108030
# 3  BRAND_9259_COUNTRY_FA79    1.042681         1.786265      1.515375
# 4  BRAND_106A_COUNTRY_E319    1.881992         1.223881      1.127864
#
#    che_pc_usd  insurance_perc_che corporation                indication  \
# 0    2.079046            1.000000   CORP_01C7              ['IND_C3B6']
# 1    2.079046            1.000000   CORP_01C7              ['IND_A496']
# 2    1.018268            1.226667   CORP_01C7  ['IND_120F', 'IND_8E8D']
# 3    1.190075            1.785253   CORP_01C7              ['IND_BAFB']
# 4    1.018876            1.076762   CORP_DF1B              ['IND_5586']
#
#   launch_date      ind_launch_date therapeutic_area  prev_perc  price_unit  \
# 0  2022-02-01  2022-08-01 00:00:00   THER_AREA_980E   0.036647    1.012037
# 1  2022-09-01                   -1   THER_AREA_6CEE   0.106925    1.121625
# 2  2022-05-01  2022-06-01 00:00:00   THER_AREA_CD59   0.041152    1.005001
# 3  2022-12-01                   -1   THER_AREA_6CEE   0.002766    1.271214
# 4  2022-12-01  2020-03-01 00:00:00   THER_AREA_96D7   0.000133    2.073953
#
#    price_month  target
# 0     1.007091     NaN
# 1    -1.000000     NaN
# 2    -1.000000     NaN
# 3    -1.000000     NaN
# 4    -1.000000     NaN

# %%
def split_data_and_check_ratios(train, year=2022):
    """
    Split the data into train and test sets based on the specified year,
    and compute the actual ratio of `drug_id`s with and without historical data.
    
    :param train: The original dataset.
    :param year: The year to use for splitting the test set.
    :return: train (before the specified year), test (the specified year), 
             ratio of `drug_id`s with historical data, ratio of `drug_id`s without historical data.
    """
    print(f"\nOriginal Dataset shape (Before Splitting): {train.shape}")
    # Ensure `date` column is in datetime format
    train["date"] = pd.to_datetime(train["date"])
    
    # Split the data: test = specified year, train = before specified year
    test = train[train["date"].dt.year == year]
    train = train[train["date"].dt.year < year]
    
    # Identify `drug_id`s with historical data (appear in train) and no historical data (do not appear in train)
    drug_ids_with_history = set(train["drug_id"].unique())
    drug_ids_no_history = set(test["drug_id"].unique()) - drug_ids_with_history
    
    # Compute the actual ratio of `drug_id`s with and without historical data
    total_drug_ids = len(drug_ids_with_history) + len(drug_ids_no_history)
    ratio_with_history = len(drug_ids_with_history) / total_drug_ids
    ratio_no_history = len(drug_ids_no_history) / total_drug_ids
    
    # Display the actual ratios
    print(f"\nOriginal Dataset Ratios (Before Splitting):")
    print(f"\nOriginal train Dataset shape (Before Splitting): {train.shape}")
    print(f"\nOriginal test Dataset shape (Before Splitting): {test.shape}")
    print(f"Proportion of `drug_id`s with historical data: {ratio_with_history:.4f}")
    print(f"Proportion of `drug_id`s without historical data: {ratio_no_history:.4f}")
    print(f"drug_ids_with_history:\n {drug_ids_with_history}")
    print(f"drug_ids_no_history:\n {drug_ids_no_history}")
    
    return train, test, ratio_with_history, ratio_no_history

# %% [markdown]
# # checking actual splits

# %%
# train['date'] = pd.to_datetime(train['date'])

# # Define years to remove
# years_to_remove = [2021]

# # Filter out rows for those years
# train = train[~train['date'].dt.year.isin(years_to_remove)]



# # Verify the unique years in the filtered dataset
# print(train['date'].dt.year.unique())

# %%
original = pd.concat([train, test])
original['date'] = pd.to_datetime(original['date'])
yearly_counts = original.groupby(original['date'].dt.year).size()
yearly_counts
# Out:
# date
# 2014      508
# 2015     3553
# 2016     7523
# 2017    12516
# 2018    16697
# 2019    20481
# 2020    21388
# 2021    19921
# 2022    16330
# 2023     1769
# dtype: int64

# %%
train, test, ratio_with_history, ratio_no_history = split_data_and_check_ratios(original, year=2023)
# Out:
# Original Dataset shape (Before Splitting): (120686, 19)
#
# Original Dataset Ratios (Before Splitting):
#
# Original train Dataset shape (Before Splitting): (118917, 19)
#
# Original test Dataset shape (Before Splitting): (1769, 19)
# Proportion of `drug_id`s with historical data: 0.9885
# Proportion of `drug_id`s without historical data: 0.0115
# drug_ids_with_history:
#  {'DRUG_ID_1D4E', 'DRUG_ID_47B7', 'DRUG_ID_F923', 'DRUG_ID_2757', 'DRUG_ID_C291', 'DRUG_ID_6705', 'DRUG_ID_45AB', 'DRUG_ID_E0F1', 'DRUG_ID_E8D6', 'DRUG_ID_52A5', 'DRUG_ID_98D8', 'DRUG_ID_D5FC', 'DRUG_ID_482D', 'DRUG_ID_83FC', 'DRUG_ID_E73F', 'DRUG_ID_7E51', 'DRUG_ID_FDD8', 'DRUG_ID_032B', 'DRUG_ID_503F', 'DRUG_ID_883A', 'DRUG_ID_7DCA', 'DRUG_ID_B15F', 'DRUG_ID_B4D3', 'DRUG_ID_45DC', 'DRUG_ID_318B', 'DRUG_ID_C7D2', 'DRUG_ID_F784', 'DRUG_ID_FD54', 'DRUG_ID_EE5B', 'DRUG_ID_933E', 'DRUG_ID_3416', 'DRUG_ID_A5ED', 'DRUG_ID_4C1D', 'DRUG_ID_94A5', 'DRUG_ID_CD87', 'DRUG_ID_D450', 'DRUG_ID_6087', 'DRUG_ID_30F8', 'DRUG_ID_A874', 'DRUG_ID_0259', 'DRUG_ID_B2B0', 'DRUG_ID_C629', 'DRUG_ID_5417', 'DRUG_ID_A22C', 'DRUG_ID_F81B', 'DRUG_ID_FAE7', 'DRUG_ID_3AF2', 'DRUG_ID_1315', 'DRUG_ID_1E6E', 'DRUG_ID_E85F', 'DRUG_ID_3393', 'DRUG_ID_79D8', 'DRUG_ID_2D67', 'DRUG_ID_1A8A', 'DRUG_ID_B8A8', 'DRUG_ID_B028', 'DRUG_ID_026E', 'DRUG_ID_FADD', 'DRUG_ID_D6F0', 'DRUG_ID_A82E', 'DRUG_ID_AA88', 'DRUG_ID_F978', 'DRUG_ID_957C', 'DRUG_ID_AF8B', 'DRUG_ID_B24A', 'DRUG_ID_372D', 'DRUG_ID_0B7B', 'DRUG_ID_B9AF', 'DRUG_ID_7A63', 'DRUG_ID_3A6F', 'DRUG_ID_6CE8', 'DR
_BF8E', 'DRUG_ID_CC22', 'DRUG_ID_DD95', 'DRUG_ID_24A2', 'DRUG_ID_A347', 'DRUG_ID_E359', 'DRUG_ID_1E78', 'DRUG_ID_1C54', 'DRUG_ID_F565', 'DRUG_ID_C2AD', 'DRUG_ID_7773', 'DRUG_ID_116F', 'DRUG_ID_E219', 'DRUG_ID_8B51', 'DRUG_ID_92F5', 'DRUG_ID_F7F9', 'DRUG_ID_4DF9', 'DRUG_ID_A7D8', 'DRUG_ID_645E', 'DRUG_ID_4AD9', 'DRUG_ID_E354', 'DRUG_ID_3EDB', 'DRUG_ID_BE19', 'DRUG_ID_88B1', 'DRUG_ID_B236', 'DRUG_ID_B8BC', 'DRUG_ID_7410', 'DRUG_ID_4BB7', 'DRUG_ID_F2CE', 'DRUG_ID_4450', 'DRUG_ID_A844', 'DRUG_ID_CE49', 'DRUG_ID_23D7', 'DRUG_ID_F3CA', 'DRUG_ID_CDD9', 'DRUG_ID_F617', 'DRUG_ID_B633', 'DRUG_ID_FD89', 'DRUG_ID_37BB', 'DRUG_ID_3210', 'DRUG_ID_25F1', 'DRUG_ID_149E', 'DRUG_ID_C604', 'DRUG_ID_32F5', 'DRUG_ID_0E7C', 'DRUG_ID_8AB0', 'DRUG_ID_EC3A', 'DRUG_ID_37C9', 'DRUG_ID_C94D', 'DRUG_ID_BBEC', 'DRUG_ID_B33A', 'DRUG_ID_F2B9', 'DRUG_ID_AEE7', 'DRUG_ID_EEEA', 'DRUG_ID_BE95', 'DRUG_ID_2331', 'DRUG_ID_25C4', 'DRUG_ID_0C4E', 'DRUG_ID_714D', 'DRUG_ID_0476', 'DRUG_ID_BD35', 'DRUG_ID_2A56', 'DRUG_ID_74AA', 'DRUG_ID_92F4', 'DRUG_ID_2D81', 'DRUG_ID_DBE1', 'DRUG_ID_E2D5', 'DRUG_ID_C901', 'DRUG_ID_74A6' ...
# drug_ids_no_history:
#  {'DRUG_ID_2910', 'DRUG_ID_E70D', 'DRUG_ID_4612'}

# %% [markdown]
# the original data has 98% data with historical drug_ids and 2% drug_ids with no historical data, and the test set has around 2000 values. We will try to replicate the test set(since we are no longer in the hackathon ) to test modelling and understand how to improve it - this is mainly known as backtesting

# %% [markdown]
# # making different test sets

# %% [markdown]
# the train data has 118917 rows , we will use year 2022 as the new test set and replicate the original test set.
# - In 2022 we see there are 16330 rows, but we need only ~2000 rows with ~98% drug_ids with historical data and ~2% without historical data
# - I am just sampling and trying to replicate 8 different datasets ( i used only 3 of them in the end) with the same distribution and shape of orginial test set
# - with this I can experiment with our predictions on the replicated test sets and understand how our final metric functions, and it is actually very close to what results we ended up with in the hackathon where are final score was 0.03101447 (18th overall ) , the best results where ~0.0100 (top 5)
# - this notebooks aims to achieve ~0.01

# %%
def create_balanced_test_set(test, size=2000, history_ratio=0.5, random_state=None):
    """
    Create a balanced test set with a mix of `drug_id`s with and without historical data.
    
    :param test: The test data.
    :param size: Desired size of the test set.
    :param history_ratio: Proportion of `drug_id`s with historical data.
    :param random_state: Seed for reproducibility.
    :return: A balanced test set, list of `drug_id`s with history, list of `drug_id`s without history.
    
    
    """
    print(f'creating test set no {random_state}, with random state {random_state} ')
    
    # Calculate the number of rows for `drug_id`s with and without historical data
    n_history = int(size * history_ratio)
    n_no_history = size - n_history
    
    # Sample `drug_id`s with historical data
    history_drugs = test[test["has_history"]].sample(n=n_history, replace=True, random_state=random_state)
    
    # Sample `drug_id`s without historical data
    no_history_drugs = test[~test["has_history"]].sample(n=n_no_history, replace=True, random_state=random_state)
    
    # Combine the samples into a balanced test set
    balanced_test = pd.concat([history_drugs, no_history_drugs]).sample(frac=1, random_state=random_state).reset_index(drop=True)
    
    # Extract `drug_id`s with and without historical data
    history_drug_ids = history_drugs["drug_id"].unique().tolist()
    no_history_drug_ids = no_history_drugs["drug_id"].unique().tolist()
    
    return balanced_test, history_drug_ids, no_history_drug_ids

# Load your dataset (replace `train` with your actual dataset)
# train = pd.read_csv("your_dataset.csv")

# Split the data and check the actual ratios
train, test, ratio_with_history, ratio_no_history = split_data_and_check_ratios(train, year=2022)

# Add a column to `test` indicating whether each `drug_id` has historical data
test["has_history"] = test["drug_id"].isin(set(train["drug_id"].unique()))

# Create multiple test sets with fixed random seeds for reproducibility
num_test_sets = 8  # Number of test sets to create
test_sets = [create_balanced_test_set(test, size=2000, history_ratio=ratio_with_history, random_state=i) for i in range(num_test_sets)]

# Check the resulting test sets and print `drug_id`s
for i, (test_set, history_drug_ids, no_history_drug_ids) in enumerate(test_sets):
    
    print(f"\nTest Set {i+1} Shape:", test_set.shape)
    print("Proportion of `drug_id`s with historical data:", test_set["has_history"].mean())
    print("`drug_id`s with historical data:", history_drug_ids)
    print("`drug_id`s without historical data:", no_history_drug_ids)
# Out:
# Original Dataset shape (Before Splitting): (118917, 19)
#
# Original Dataset Ratios (Before Splitting):
#
# Original train Dataset shape (Before Splitting): (102587, 19)
#
# Original test Dataset shape (Before Splitting): (16330, 19)
# Proportion of `drug_id`s with historical data: 0.9805
# Proportion of `drug_id`s without historical data: 0.0195
# drug_ids_with_history:
#  {'DRUG_ID_1D4E', 'DRUG_ID_47B7', 'DRUG_ID_F923', 'DRUG_ID_2757', 'DRUG_ID_C291', 'DRUG_ID_6705', 'DRUG_ID_45AB', 'DRUG_ID_E0F1', 'DRUG_ID_E8D6', 'DRUG_ID_52A5', 'DRUG_ID_98D8', 'DRUG_ID_D5FC', 'DRUG_ID_482D', 'DRUG_ID_83FC', 'DRUG_ID_E73F', 'DRUG_ID_7E51', 'DRUG_ID_FDD8', 'DRUG_ID_032B', 'DRUG_ID_503F', 'DRUG_ID_883A', 'DRUG_ID_7DCA', 'DRUG_ID_B15F', 'DRUG_ID_B4D3', 'DRUG_ID_45DC', 'DRUG_ID_318B', 'DRUG_ID_C7D2', 'DRUG_ID_F784', 'DRUG_ID_FD54', 'DRUG_ID_EE5B', 'DRUG_ID_933E', 'DRUG_ID_3416', 'DRUG_ID_A5ED', 'DRUG_ID_4C1D', 'DRUG_ID_94A5', 'DRUG_ID_CD87', 'DR
#
#    prev_perc  price_unit  price_month    target  has_history
# 0   0.017877    1.021988     1.017883  1.494379         True
# 1   0.000227    1.003476     1.039887  1.005237         True
# 2   0.000117    1.199389     1.871923  2.650532         True
# 3   0.018808    1.301499     1.849886  2.074116         True
# 4   0.000110    1.081038     1.710991  2.355909         True

# %%
test_sets[1][0][test_sets[1][0]["has_history"] == False]["drug_id"].nunique()
# Out:
# 4

# %%
test_sets[2][0].head()
# Out:
#         date       drug_id       brand       country               cluster_nl  \
# 0 2022-05-01  DRUG_ID_3A6F  BRAND_9FCC  COUNTRY_0309  BRAND_9FCC_COUNTRY_0309
# 1 2022-11-01  DRUG_ID_45AB  BRAND_76D6  COUNTRY_907E  BRAND_76D6_COUNTRY_907E
# 2 2022-08-01  DRUG_ID_F3CA  BRAND_0E5A  COUNTRY_FA79  BRAND_0E5A_COUNTRY_FA79
# 3 2022-04-01  DRUG_ID_1B64  BRAND_FE66  COUNTRY_53A5  BRAND_FE66_COUNTRY_53A5
# 4 2022-08-01  DRUG_ID_BE95  BRAND_F148  COUNTRY_8B47  BRAND_F148_COUNTRY_8B47
#
#    population  public_perc_che  che_perc_gdp  che_pc_usd  insurance_perc_che  \
# 0    1.497382         1.890506      2.000000    1.759886            2.032511
# 1    1.356278         1.843706      1.918488    1.462828            1.040000
# 2    1.042912         1.794286      1.529843    1.183443            1.785806
# 3    1.994766         2.000000      2.007093    1.680087            1.986667
# 4    1.025199        -1.000000     -1.000000   -1.000000           -1.000000
#
#   corporation                                        indication launch_date  \
# 0   CORP_01C7  ['IND_DA0B', 'IND_9D10', 'IND_BD8B', 'IND_0883']  2017-08-01
# 1   CORP_A682                                      ['IND_8EA5']  2018-01-01
# 2   CORP_09BB                                      ['IND_F338']  2021-03-01
# 3   CORP_39F7                                      ['IND_B2EF']  2020-03-01
# 4   CORP_01C7                                      ['IND_F338']  2019-03-01
#
#        ind_launch_date therapeutic_area  prev_perc  price_unit  price_month  \
# 0                   -1   THER_AREA_96D7   0.032827    1.212213     1.129994
# 1                   -1   THER_AREA_96D7   0.015903    2.536226     3.064331
# 2  2021-08-01 00:00:00   THER_AREA_96D7   0.007260    1.282841     1.302948
# 3                   -1   THER_AREA_96D7   0.002428    1.195899     1.277728
# 4  2020-03-01 00:00:00   THER_AREA_96D7   0.003552    1.742377    -1.000000
#
#      target  has_history
# 0  1.527548         True
# 1  9.301589         True
# 2  1.068189         True
# 3  1.027430         True
# 4  1.142243         True

# %% [markdown]
# # Feature engineering

# %%
def feature_engineering(train, test):
    """
    Perform feature engineering on the train and test datasets.
    
    :param train: The training dataset.
    :param test: The test dataset.
    :return: targets (for evaluation), data (combined train and test with engineered features).
    """
    # Drop the 'has_history' column from the test set
    test.drop(columns="has_history", inplace=True)
    print("Dropped 'has_history' column from the test set.")

    # Create targets for evaluation
    targets = test[["date", "cluster_nl", "target"]].copy()
    test["target"] = np.nan
    print("Created 'targets' for evaluation.")

    # Drop unnecessary columns
    cols_to_drop = ['che_perc_gdp', 'insurance_perc_che', 'ind_launch_date', 'price_month']
    train.drop(columns=cols_to_drop, inplace=True)
    test.drop(columns=cols_to_drop, inplace=True)
    print(f"Dropped unnecessary columns: {cols_to_drop}.")

    # Handle missing values in 'public_perc_che'
    train.public_perc_che = train.public_perc_che.replace(-1, np.nan)
    test.public_perc_che = test.public_perc_che.replace(-1, np.nan)
    train['public_perc_che'].fillna(train.groupby(["country"])['public_perc_che'].transform('median'), inplace=True)
    test['public_perc_che'].fillna(test.groupby(["country"])['public_perc_che'].transform('median'), inplace=True)
    train.public_perc_che = train.public_perc_che.fillna(train.public_perc_che.median())
    test.public_perc_che = test.public_perc_che.fillna(train.public_perc_che.median())
    print("Handled missing values in 'public_perc_che'.")

    # Handle missing values in 'che_pc_usd'
    train.che_pc_usd = train.che_pc_usd.replace(-1, np.nan)
    test.che_pc_usd = test.che_pc_usd.replace(-1, np.nan)
    train['che_pc_usd'].fillna(train.groupby(["country"])['che_pc_usd'].transform('median'), inplace=True)
    test['che_pc_usd'].fillna(test.groupby(["country"])['che_pc_usd'].transform('median'), inplace=True)
    train.che_pc_usd = train.che_pc_usd.fillna(train.che_pc_usd.median())
    test.che_pc_usd = test.che_pc_usd.fillna(train.che_pc_usd.median())
    print("Handled missing values in 'che_pc_usd'.")

    # Handle missing values in 'price_unit'
    train.price_unit = train.price_unit.replace(-1, np.nan)
    test.price_unit = test.price_unit.replace(-1, np.nan)
    train['price_unit'].fillna(train.groupby(["drug_id"])['price_unit'].transform('median'), inplace=True)
    test['price_unit'].fillna(test.groupby(["drug_id"])['price_unit'].transform('median'), inplace=True)
    print("Handled missing values in 'price_unit'.")

    # Check for remaining missing values
    print("Missing values in train set:")
    print(train.isnull().sum())
    print("Missing values in test set:")
    print(test.isnull().sum())

    # Encode categorical features
    cat_feats = ["indication", "drug_id", "brand", "country", "therapeutic_area", "corporation"]
    for c in cat_feats:
        le = preprocessing.LabelEncoder()
        le.fit(pd.concat((train, test))[c])
        train[c] = le.transform(train[c])
        test[c] = le.transform(test[c])
    print("Encoded categorical features.")

    # Extract date-related features for train set
    train['date'] = pd.to_datetime(train['date'])
    train['launch_date'] = pd.to_datetime(train['launch_date'])
    train['quarter'] = train['date'].dt.quarter.astype("int16")
    train['month'] = train['date'].dt.month.astype("int16")
    train['day'] = train['date'].dt.day.astype("int16")
    train['weekday'] = train['date'].dt.weekday.astype("int16")
    train['quarter_l'] = train['launch_date'].dt.quarter.astype("int16")
    train['month_l'] = train['launch_date'].dt.month.astype("int16")
    train['day_l'] = train['launch_date'].dt.day.astype("int16")
    train['weekday_l'] = train['launch_date'].dt.weekday.astype("int16")
    train['days'] = (train['date'] - train['launch_date']) / np.timedelta64(1, 'D')
    print("Extracted date-related features for train set.")

    # Extract date-related features for test set
    test['date'] = pd.to_datetime(test['date'])
    test['launch_date'] = pd.to_datetime(test['launch_date'])
    test['quarter'] = test['date'].dt.quarter.astype("int16")
    test['month'] = test['date'].dt.month.astype("int16")
    test['day'] = test['date'].dt.day.astype("int16")
    test['weekday'] = test['date'].dt.weekday.astype("int16")
    test['quarter_l'] = test['launch_date'].dt.quarter.astype("int16")
    test['month_l'] = test['launch_date'].dt.month.astype("int16")
    test['day_l'] = test['launch_date'].dt.day.astype("int16")
    test['weekday_l'] = test['launch_date'].dt.weekday.astype("int16")
    test['days'] = (test['date'] - test['launch_date']) / np.timedelta64(1, 'D')
    print("Extracted date-related features for test set.")

    # Drop 'launch_date' column
    train.drop(['launch_date'], axis=1, inplace=True)
    test.drop(['launch_date'], axis=1, inplace=True)
    print("Dropped 'launch_date' column.")

    # Check for drug_ids in test set that are not in train set
    new_drug_ids = list(set(test.drug_id) - set(train.drug_id))
    print(f"Number of new drug_ids in test set: {len(new_drug_ids)}")

    # Add a 'select' column to distinguish train and test sets
    train["select"] = "train"
    test["select"] = "test"

    # Combine train and test sets
    data = pd.concat((train, test))
    print("Combined train and test sets into 'data'.")

    # Sort targets for evaluation
    targets = targets.sort_values(["cluster_nl", "date"])
    print("Sorted 'targets' for evaluation.")

    return targets, data

# %%
# train = train[train['date'].dt.year != 2020]
print(train['date'].dt.year.unique())  # Should not include 2020
# Out:
# [2014 2015 2016 2017 2018 2019 2020 2021]

# %%
dataset_no=2

# Assuming `train` and `test` are already loaded
targets1, data = feature_engineering(train, test_sets[dataset_no][0])


data.head()
# Save the processed data to a CSV file
data.to_csv(f"../abhi_data/data_dummy_2022_{dataset_no}_final.csv", index=False)
print("Saved processed data to 'data_dummy_2022.csv'.")
# Out:
# Dropped 'has_history' column from the test set.
# Created 'targets' for evaluation.
# Dropped unnecessary columns: ['che_perc_gdp', 'insurance_perc_che', 'ind_launch_date', 'price_month'].
# Handled missing values in 'public_perc_che'.
# Handled missing values in 'che_pc_usd'.
# Handled missing values in 'price_unit'.
# Missing values in train set:
# date                0
# drug_id             0
# brand               0
# country             0
# cluster_nl          0
# population          0
# public_perc_che     0
# che_pc_usd          0
# corporation         0
# indication          0
# launch_date         0
# therapeutic_area    0
# prev_perc           0
# price_unit          0
# target              0
# dtype: int64
# Missing values in test set:
# date                   0
# drug_id                0
# brand                  0
# country                0
# cluster_nl             0
# population             0
# public_perc_che        0
# che_pc_usd             0
# corporation            0
# indication             0
# launch_date            0
# therapeutic_area       0
# prev_perc              0
# price_unit             0
# target              2000
# dtype: int64
# Encoded categorical features.
# Extracted date-related features for train set.
# Extracted date-related features for test set.
# Dropped 'launch_date' column.
# Number of new drug_ids in test set: 4
# Combined train and test sets into 'data'.
# Sorted 'targets' for evaluation.
# Saved processed data to 'data_dummy_2022.csv'.

# %%
data.tail()
# Out:
#            date  drug_id  brand  country               cluster_nl  population  \
# 1995 2022-05-01      171     19        2  BRAND_076F_COUNTRY_0C7D    1.121505
# 1996 2022-06-01       55    352       33  BRAND_9FCC_COUNTRY_9488    1.276059
# 1997 2022-01-01       93    527       32  BRAND_EB6C_COUNTRY_907E    1.356278
# 1998 2022-03-01      143    250       37  BRAND_6FE1_COUNTRY_B6AE    1.040685
# 1999 2022-06-01       55    221       36  BRAND_62C7_COUNTRY_AE54   12.767484
#
#       public_perc_che  che_pc_usd  corporation  indication  therapeutic_area  \
# 1995         1.926795    1.127497           59         101                 9
# 1996         1.809115    1.179931            0         220                 9
# 1997         1.843706    1.462828           35          30                 7
# 1998         1.697551    1.336985            5         152                 7
# 1999         1.552239    1.092886            0         222                 9
#
#       prev_perc  price_unit  target  quarter  month  day  weekday  quarter_l  \
# 1995   0.008770    1.662617     NaN        2      5    1        6          3
# 1996   0.043968    1.252813     NaN        2      6    1        2          2
# 1997   0.015002    1.025082     NaN        1      1    1        5          2
# 1998   0.128669    1.128001     NaN        1      3    1        1          3
# 1999   0.007849    1.035044     NaN        2      6    1        2          1
#
#       month_l  day_l  weekday_l    days select
# 1995        7      1          0  1035.0   test
# 1996        4      1          2   791.0   test
# 1997        5      1          1  1341.0   test
# 1998        8      1          5   577.0   test
# 1999        3      1          0   457.0   test

# %%
targets1.head()
# Out:
#            date               cluster_nl    target
# 1980 2022-06-01  BRAND_0056_COUNTRY_06E4  1.112130
# 320  2022-01-01  BRAND_0056_COUNTRY_0C7D  1.217491
# 1884 2022-04-01  BRAND_0056_COUNTRY_0C7D  1.209845
# 1728 2022-10-01  BRAND_0056_COUNTRY_0C7D  1.271516
# 154  2022-11-01  BRAND_0056_COUNTRY_0C7D  1.311337

# %%
targets1.isna().sum()
# Out:
# date          0
# cluster_nl    0
# target        0
# dtype: int64

# %% [markdown]
# # modelling

# %%
subs = pd.DataFrame(columns=['date', 'cluster_nl', 'target']) 
subs
# Out:
# Empty DataFrame
# Columns: [date, cluster_nl, target]
# Index: []

# %%
data = pd.read_csv(f"../abhi_data/data_dummy_2022_{dataset_no}_final.csv")
data = data.reset_index(drop=True)
data.head()
# Out:
#          date  drug_id  brand  country               cluster_nl  population  \
# 0  2014-06-01      120    109       28  BRAND_354E_COUNTRY_88A3    1.008039
# 1  2014-06-01      222    219       30  BRAND_626D_COUNTRY_8B47    1.023562
# 2  2014-06-01      235    151       28  BRAND_45D9_COUNTRY_88A3    1.008039
# 3  2014-06-01       24    477       13  BRAND_D724_COUNTRY_445D    1.253186
# 4  2014-06-01      148    157       43  BRAND_4887_COUNTRY_D8B0    1.639352
#
#    public_perc_che  che_pc_usd  corporation  indication  therapeutic_area  \
# 0         1.835821    1.209114          115         193                10
# 1         1.835821    1.472378            0          27                 9
# 2         1.835821    1.209114           27         183                 9
# 3         1.805970    1.851280           54         185                 7
# 4         1.880597    1.791199           33          41                 7
#
#    prev_perc  price_unit    target  quarter  month  day  weekday  quarter_l  \
# 0   0.028367    1.013784  1.000784        2      6    1        6          2
# 1   0.000047    1.626677  1.000000        2      6    1        6          2
# 2   0.001502    3.144874  1.002258        2      6    1        6          2
# 3   0.001304    1.213446  1.068761        2      6    1        6          2
# 4   0.054467    1.008708  1.036312        2      6    1        6          2
#
#    month_l  day_l  weekday_l  days select
# 0        6      1          6   0.0  train
# 1        6      1          6   0.0  train
# 2        6      1          6   0.0  train
# 3        6      1          6   0.0  train
# 4        6      1          6   0.0  train

# %%
data.loc[data['select'] == 'train', 'target'] = np.log1p(data.loc[data['select'] == 'train', 'target'])

# %%
drug_ids = data[data.select == "test"].drug_id.unique()
print( len(drug_ids) )
# Out:
# 195

# %% [markdown]
# ## forecast recent

# %% [markdown]
# ### normal

# %%
def get_forecast(q_ind):

    db = drug_.copy()
    cols_to_drop = ['date', 'corporation', 'cluster_nl','select','target']
    db = db.drop(cols_to_drop, axis = 1)
    db[['therapeutic_area','indication','country','brand']] = db[['therapeutic_area','indication','country','brand']].astype(object)
    db[['quarter','month','day','weekday','quarter_l','month_l','day_l','weekday_l']] = db[['quarter','month','day','weekday','quarter_l','month_l','day_l','weekday_l']].astype(object)
    Dg = gower.gower_matrix(db)

    db = drug_.copy()
    cols_to_drop = ['date','cluster_nl','corporation','select','target']
    tmp = db.drop(cols_to_drop, axis = 1)
    tmp_cols = pd.get_dummies(tmp[['therapeutic_area','indication','country','brand','quarter','month','day','weekday','quarter_l','month_l','day_l','weekday_l']].astype(str))
    cols_to_drop = ['therapeutic_area','indication','country','brand','quarter','month','day','weekday','quarter_l','month_l','day_l','weekday_l']
    tmp = tmp.drop(cols_to_drop, axis = 1)
    db = pd.concat((tmp,tmp_cols), axis=1)
    scaler_ = MinMaxScaler()
    db_n = scaler_.fit_transform(db)
    db_n = pd.DataFrame(data=db_n, columns=db.columns, index=db.index)
    De = squareform( pdist(db_n.values) )
    
    r_num = list( db_n.index).index( q_ind )

    selects = np.concatenate((np.argsort( Dg[r_num,:] )[:20], np.argsort( De[r_num,:] )[:20]))
    selects = np.unique( selects )
    res_inds = db_n.index[ selects ]

    t_values = drug_.loc[res_inds, "target"].values
    out = np.median(t_values[~np.isnan(t_values)])

    return out

# %%
def get_forecast_country(q_ind):
    f1 = data["country"] == q.loc[q_ind].country

    db = data[ f1 ].copy()
    db[['therapeutic_area','indication','country','brand']] = db[['therapeutic_area','indication','country','brand']].astype(object)
    db[['quarter','month','day','weekday','quarter_l','month_l','day_l','weekday_l']] = db[['quarter','month','day','weekday','quarter_l','month_l','day_l','weekday_l']].astype(object)

    db1 = db.copy()
    cols_to_drop = ['date', 'corporation', 'cluster_nl','select','target','country']
    db1 = db1.drop(cols_to_drop, axis = 1)
    Dg1 = gower.gower_matrix(db1)

    r_num = list(db.index).index( q_ind )

    selects = np.argsort( Dg1[r_num,:] )[:16]
    res_inds = db.index[ selects ]

    t_values = db.loc[res_inds, "target"].values
    out = np.median(t_values[~np.isnan(t_values)])
    
    return out


# def get_forecast_country(q_ind):
#     # Filter data for the same country
#     country = q.loc[q_ind].country
#     db = data[data["country"] == country].copy()
    
#     # Drop unnecessary columns
#     cols_to_drop = ['date', 'corporation', 'cluster_nl', 'select', 'target', 'country']
#     db1 = db.drop(cols_to_drop, axis=1)
    
#     # Convert categorical columns to dummy variables
#     tmp = db1.copy()
#     tmp_cols = pd.get_dummies(tmp[['therapeutic_area', 'indication', 'brand', 'quarter', 'month', 'day', 'weekday', 'quarter_l', 'month_l', 'day_l', 'weekday_l']].astype(str))
#     cols_to_drop = ['therapeutic_area', 'indication', 'brand', 'quarter', 'month', 'day', 'weekday', 'quarter_l', 'month_l', 'day_l', 'weekday_l']
#     tmp = tmp.drop(cols_to_drop, axis=1)
#     db1 = pd.concat((tmp, tmp_cols), axis=1)
    
#     # Normalize the data
#     scaler_ = MinMaxScaler()
#     db1_n = scaler_.fit_transform(db1)
#     db1_n = pd.DataFrame(data=db1_n, columns=db1.columns, index=db1.index)
    
#     # Fit KNN model with Euclidean distance
#     knn = NearestNeighbors(n_neighbors=4, metric='euclidean')
#     knn.fit(db1_n.values)
    
#     # Find the nearest neighbors for the query point
#     r_num = list(db1_n.index).index(q_ind)
#     distances, indices = knn.kneighbors([db1_n.iloc[r_num].values])
    
#     # Get the target values of the nearest neighbors
#     t_values = db.iloc[indices[0]]["target"].values
#     out = np.mean(t_values[~np.isnan(t_values)])
    
#     return out

# %% [markdown]
# ## lag

# %%
## more lag features
def get_features( ndf, id_ ):
    # Lags
    for l_ in [1, 2,4,6,8,10,12]:
        ndf[str(id_)+"_lag_"+str(l_)] = ndf.groupby("cluster_nl")[id_].shift(l_)
    
    # Rolling means and stds
    for r_ in [2,4,6,8,10,12]:
        ndf[str(id_)+"_rmean_"+str(r_)] = ndf.groupby("cluster_nl")[id_].transform(lambda x : x.rolling(r_, closed = 'left').mean())
        ndf[str(id_)+"_rstd_"+str(r_)] = ndf.groupby("cluster_nl")[id_].transform(lambda x : x.rolling(r_, closed = 'left').std())
    
    # Trends
    ndf[str(id_)+"_sell_trend"] = (ndf[str(id_)+"_lag_1"] - ndf[str(id_)+"_rmean_2"]).astype(np.float16)
    
    # Rolling Max
    ndf[str(id_)+"_rmax_2"] = ndf.groupby("cluster_nl")[id_].transform(lambda x: x.rolling(window=2, closed="left").max()).astype(np.float16)

    # Prices
    ndf["price_mean"] = ndf.groupby("cluster_nl")["price_unit"].transform(lambda x: x.mean())
    ndf["price_max"] = ndf.groupby("cluster_nl")["price_unit"].transform(lambda x: x.max())
    ndf["price_min"] = ndf.groupby("cluster_nl")["price_unit"].transform(lambda x: x.min())
    ndf["price_unit_lag_1"] = ndf.groupby("cluster_nl")["price_unit"].shift(1)
    ndf["price_unit_rmean_3"] = ndf.groupby("cluster_nl")["price_unit"].transform(lambda x : x.rolling(2, closed='left').mean())
    ndf["price_unit_rstd_3"] = ndf.groupby("cluster_nl")["price_unit"].transform(lambda x : x.rolling(2, closed ='left').std())

# %% [markdown]
# ## modelling pipleine

# %% [markdown]
# ### abhi pipeline

# %% [markdown]
# ### normal

# %%
print(drug_ids)
for d_index in drug_ids :
    ##### part 1 
    drug_ = data[ (data["drug_id"] == d_index) ]
    drug_.drop(columns=["drug_id"], inplace=True)
    
    print( "drug_id", d_index)
    print( drug_.shape )
    print( drug_["select"].value_counts() )
    # display(drug_.head())
    print("part 1 done")
    ##### part 2     
    keep = []
    ignore = []
    for u in drug_.cluster_nl.unique():
        n1 = len(drug_[ (drug_["cluster_nl"] == u ) & ( drug_["select"] == "train") ])
        n2 = len(drug_[ (drug_["cluster_nl"] == u ) & ( drug_["select"] == "test") ])
        print(u,n1,n2, n1-n2)
        if n1 < 13 :
            ignore.append(u)
        else:
            keep.append(u)

    print( "keep/ignore", len(keep), len(ignore) )
    # display(drug_.head())
    print("part 2 done")

    ##### part 3    
    q = drug_[ drug_["cluster_nl"].isin(ignore) & (drug_['select']=="test")]
    
    if len(q) > 0 :
        targets = []
        for idx in list(q.index):
            
            
            # f = get_forecast_country( idx )
            # if np.isnan(f):
            #     f = get_forecast( idx )
            
            # f_1 = get_forecast_country( idx )
            # f_2 = get_forecast( idx )
            
            # if not np.isnan(f_1) and not np.isnan(f_2):
            #     f = 0.5 * (f_1 + f_2)
            # else:
            #     if not np.isnan(f_1):
            #         f = f_1
            #     else:
            #         f = f_2
            
            
            
            f = get_forecast( idx )
            if np.isnan(f):
                f = get_forecast_country( idx )
            
            
            # drug_samples = drug_[drug_["select"] == "train"]  # Filter to training data
            # if len(drug_samples) >= 20:  # Ensure there are at least 20 samples
            #     f = get_forecast(idx)
            # else:
            #     # If not enough samples, use country-level forecast
            #     f = get_forecast_country(idx)
            
            # # If the forecast is still NaN, fall back to country-level forecast
            # if np.isnan(f):
            #     f = get_forecast_country(idx)
            
            
            targets.append( f )
        q["target"] = targets
        subs = pd.concat( (subs, q[["date","cluster_nl","target"]]) )

    print("ignores done.")
    # display(drug_.head())
    print("part 3 done")

    ##### part 4  
    drug_ = drug_[ drug_["cluster_nl"].isin(keep) ]
    
    if len( drug_ ) == 0:
        print("skip next")
        print("---------------------------------------")
        continue
        
    drug_train = drug_[ ~drug_.target.isnull().values ]
    drug_val = drug_[ drug_.target.isnull().values ]
    print( "data size", drug_train.shape, drug_val.shape )
    # display(drug_train.head())

    print("check", set(drug_val.cluster_nl.values) - set(drug_train.cluster_nl.values) )

    drug_train = drug_train.sort_values(["cluster_nl", "date"])
    drug_val = drug_val.sort_values(["cluster_nl", "date"])

    drug_train_n = drug_train.copy()
    drug_val_n = drug_val.copy()

    drug_val_n_com = pd.concat((drug_train_n, drug_val_n))
    drug_val_n_com = drug_val_n_com.sort_values(["cluster_nl", "date"])

    get_features( drug_val_n_com, "target" )
    print("lags done.")

    ##### part 5  
    drug_train_n = drug_val_n_com[ drug_val_n_com.index.isin( drug_train_n.index ) ]
    drug_val_n = drug_val_n_com[ drug_val_n_com.index.isin( drug_val_n.index ) ]

    drug_train_n.dropna(inplace=True)
    print("after lags", drug_train_n.shape)

    print("check", set(drug_val.cluster_nl.values) - set(drug_train.cluster_nl.values) )

    ##### part 6  
    x_train = drug_train_n.drop(['target','cluster_nl','date','select'], axis = 1)
    y_train = drug_train_n["target"].copy()

    print("train data", x_train.shape, y_train.shape)
    
    #     # Define the MAPE function
    # def mape(y_true, y_pred):
    #     return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

    # # Create a custom scorer for MAPE
    # mape_scorer = make_scorer(mape, greater_is_better=False)

    # # Define the parameter grid
    # grid = dict()
    # grid['n_estimators'] = [100, 500]
    # grid['learning_rate'] = [0.01, 0.1]
    # grid['subsample'] = [0.5, 0.7]
    # grid['max_depth'] = [3, 4]

    # # Check the number of samples
    # n_samples = x_train.shape[0]

    # if n_samples == 1:
    #     # If there's only 1 sample, fit a basic model without GridSearchCV
    #     print("Only 1 sample found. Fitting a basic model...")
    #     model = lgb.LGBMRegressor(verbose=-1, n_estimators=100, learning_rate=0.1, subsample=0.7, max_depth=3)
    #     model.fit(x_train, y_train)
    # else:
    #     # If there are more than 1 samples, use GridSearchCV with CV
    #     print(f"{n_samples} samples found. Using GridSearchCV with CV...")
    #     cv_folds = min(2, n_samples)  # Use cv=2 or cv=3, but ensure it doesn't exceed the number of samples
    #     grid_search = GridSearchCV(
    #         estimator=lgb.LGBMRegressor(verbose=-1),
    #         param_grid=grid,
    #         n_jobs=-1,
    #         cv=cv_folds,
    #         scoring=mape_scorer
    #     )
    #     grid_search.fit(x_train, y_train)
    #     model = grid_search.best_estimator_

    # # Print the model details
    # print("Model trained successfully.")
    
    
    model = lgb.LGBMRegressor(n_estimators=300, verbose = -1)
    
    model.fit(x_train, y_train)

    ##### part 7
    print("iterative fit starts")
    for u in drug_val_n.cluster_nl.unique() :
        print(u)

        tmp_train = drug_train_n[ drug_train_n["cluster_nl"] == u ]
        tmp_val = drug_val_n[ drug_val_n["cluster_nl"] == u ]

        print( len(tmp_train), len(tmp_val) )

        if len(tmp_train) != 0:
            for i in range(len(tmp_val)):

                pred = model.predict( tmp_val.drop(['target','cluster_nl','date','select'], axis = 1).iloc[[i]] )
                tmp_val.iloc[[i], tmp_val.columns.get_loc("target")] = pred

                tmp_com = pd.concat((tmp_train, tmp_val))
                get_features( tmp_com, "target" )

                tmp_val = tmp_com[ tmp_com.index.isin( tmp_val.index ) ]

        else:
            pred = model.predict( tmp_val.drop(['target','cluster_nl','date','select'], axis = 1) )
            tmp_val[ "target" ] = pred

        drug_val_n.loc[tmp_val.index] = tmp_val

    print("fit done.")

    ##### part 8
    subs = pd.concat( (subs, drug_val_n[["date","cluster_nl","target"]]) )

    print("drug done -- > next")
    print("---------------------------------------")
    
print(" -- finished -- ")
# Out:
# [ 55  61 239  22 180 207 191 104 213 174 159 217 118  95  49 167  40  85
#   73  79  29 112  58 223  66 123   1  14  64 218   9 179 166  35 242 111
#  135 198  23  65 230  93  59  24 175 141 224 156 115  84 109  21  41 101
#   89 220  98 134  50  17 110 113  15 126 249  27  78 199 127 169 209 157
#  190  51  30 228  13   0  46 206 105 193  99 147  36 192  94  92   5  48
#  203  31 251  34  81 243 171  25 165  68 194 128 133  54 153 107  71 219
#  143 234 250 196  62  28  56 235 227 186 122  26 255 201  83 161  52  43
#   19  88 129  53 232  60 148 117 205 132 236 240 164  44  39 170 162 173
#  172 216 183  63 106 150  11 187   8 114 168 176 144  75 100 229 182  42
#  160   7  18 177 202 238 152 210 149  76 231   2  16  33  47  57 212 120
#  140 245 184  70   4 154 188 138 124  82 178  12 233 237 222]
# drug_id 55
# (2740, 23)
# select
# train    2698
# test       42
# Name: count, dtype: int64
# part 1 done
# BRAND_62C7_COUNTRY_3AD0 60 0 60
# check set()
# train data (2045, 46) (2045,)
# iterative fit starts
# BRAND_62C7_COUNTRY_0C7D
# 14 1
# BRAND_62C7_COUNTRY_1007
# 41 1
# BRAND_62C7_COUNTRY_221C
# 21 1
# BRAND_62C7_COUNTRY_4D48
# 29 1
# BRAND_62C7_COUNTRY_4D5D
# 28 1
# BRAND_62C7_COUNTRY_84C8
# 32 1
# BRAND_62C7_COUNTRY_88A3
# 41 1
# BRAND_62C7_COUNTRY_8DBB
# 27 2
# BRAND_62C7_COUNTRY_B835
# 34 3
# BRAND_62C7_COUNTRY_FA79
# 42 1
# BRAND_9DA9_COUNTRY_1033
# 25 2
# BRAND_9FCC_COUNTRY_0309
# 41 3
# BRAND_9FCC_COUNTRY_1007
# 35 2
# BRAND_9FCC_COUNTRY_445D
# 42 2
# BRAND_9FCC_COUNTRY_4D48
# 32 1
# BRAND_9FCC_COUNTRY_5A54
# 43 3
# BRAND_9FCC_COUNTRY_6C16
# 36 2
# BRAND_9FCC_COUNTRY_9488
# 9 3
# BRAND_9FCC_COUNTRY_EA71
# 23 2
# BRAND_9FCC_COUNTRY_FA79
# 23 3
# BRAND_D915_COUNTRY_8DBB
# 25 1
# BRAND_D915_COUNTRY_B6AE
# 28 2
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 61
# (860, 23)
# select
# train    831
# test      29
# Name: count, dtype: int64
# part 1 done
# BRAND_76D6_COUNTRY_D8B0 55 0 55
# BRAND_76D6_COUNTRY_9891 50 1 49
# BRAND_76D6_COUNTRY_0309 53 0 53
# BRAND_76D6_COUNTRY_3AD0 49 2 47
# BRAND_76D6_COUNTRY_907E 48 3 45
# BRAND_76D6_COUNTRY_FA79 48 2 46
# BRAND_76D6_COUNTRY_D5B9 46 1 45
# BRAND_76D6_COUNTRY_6F78 45 0 45
# BRAND_ED6D_COUNTRY_4253 44 3 41
# BRAND_76D6_COUNTRY_5180 44 0 44
# BRAND_76D6_COUNTRY_4242 44 1 43
# BRAND_76D6_COUNTRY_8DBB 43 0 43
# BRAND_76D6_COUNTRY_53A5 38 1 37
# BRAND_76D6_COUNTRY_4442 37 2 35
# BRAND_76D6_COUNTRY_89F9 36 1 35
# BRAND_76D6_COUNTRY_06E4 34 4 30
# BRAND_6475_COUNTRY_9891 4 0 4
# BRAND_76D6_COUNTRY_445D 28 0 28
# BRAND_76D6_COUNTRY_0C7D 24 3 21
# BRAND_76D6_COUNTRY_C89B 20 0 20
# BRAND_76D6_COUNTRY_9488 19 1 18
# BRAND_76D6_COUNTRY_B6AE 11 0 11
# BRAND_76D6_COUNTRY_221C 8 1 7
# BRAND_76D6_COUNTRY_5FEB 3 3 0
# keep/ignore 20 4
# part 2 done
# ignores done.
# part 3 done
# data size (805, 23) (25, 23)
# check set()
# lags done.
# after lags (565, 50)
# check set()
# train data (565, 46) (565,)
# iterative fit starts
# BRAND_76D6_COUNTRY_06E4
# 22 4
# BRAND_76D6_COUNTRY_0C7D
# 12 3
# BRAND_76D6_COUNTRY_3AD0
# 37 2
# BRAND_76D6_COUNTRY_4242
# 32 1
# BRAND_76D6_COUNTRY_4442
# 25 2
# BRAND_76D6_COUNTRY_53A5
# 26 1
# BRAND_76D6_COUNTRY_89F9
# 24 1
# BRAND_76D6_COUNTRY_907E
# 36 3
# BRAND_76D6_COUNTRY_9488
# 7 1
# BRAND_76D6_COUNTRY_9891
# 38 1
# BRAND_76D6_COUNTRY_D5B9
# 34 1
# BRAND_76D6_COUNTRY_FA79
# 36 2
# BRAND_ED6D_COUNTRY_4253
# 32 3
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 239
# (293, 23)
# select
# train    271
# test      22
# Name: count, dtype: int64
# part 1 done
# BRAND_7A04_COUNTRY_53A5 25 2 23
# BRAND_0E5A_COUNTRY_89F9 23 0 23
# BRAND_0E5A_COUNTRY_9891 23 1 22
# BRAND_0E5A_COUNTRY_D8B0 23 2 21
# BRAND_7A04_COUNTRY_E319 21 1 20
# BRAND_0E5A_COUNTRY_0309 20 3 17
# BRAND_0E5A_COUNTRY_907E 19 1 18
# BRAND_7A04_COUNTRY_B835 19 2 17
# BRAND_7A04_COUNTRY_B6AE 17 1 16
# BRAND_0E5A_COUNTRY_C8F4 16 1 15
# BRAND_0E5A_COUNTRY_1007 16 1 15
# BRAND_0E5A_COUNTRY_3AD0 15 0 15
# BRAND_7A04_COUNTRY_445D 15 1 14
# BRAND_0E5A_COUNTRY_FA79 10 3 7
# BRAND_0E5A_COUNTRY_4253 9 3 6
# keep/ignore 13 2
# part 2 done
# ignores done.
# part 3 done
# data size (252, 23) (16, 23)
# check set()
# lags done.
# after lags (96, 50)
# check set()
# train data (96, 46) (96,)
# iterative fit starts
# BRAND_0E5A_COUNTRY_0309
# 8 3
# BRAND_0E5A_COUNTRY_1007
# 4 1
# BRAND_0E5A_COUNTRY_907E
# 7 1
# BRAND_0E5A_COUNTRY_9891
# 11 1
# BRAND_0E5A_COUNTRY_C8F4
# 4 1
# BRAND_0E5A_COUNTRY_D8B0
# 11 2
# BRAND_7A04_COUNTRY_445D
# 3 1
# BRAND_7A04_COUNTRY_53A5
# 13 2
# BRAND_7A04_COUNTRY_B6AE
# 5 1
# BRAND_7A04_COUNTRY_B835
# 7 2
# BRAND_7A04_COUNTRY_E319
# 9 1
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 22
# (47, 23)
# select
# train    39
# test      8
# Name: count, dtype: int64
# part 1 done
# BRAND_FE66_COUNTRY_53A5 22 4 18
# BRAND_FE66_COUNTRY_D8B0 17 4 13
# keep/ignore 2 0
# part 2 done
# ignores done.
# part 3 done
# data size (39, 23) (8, 23)
# check set()
# lags done.
# after lags (15, 50)
# check set()
# train data (15, 46) (15,)
# iterative fit starts
# BRAND_FE66_COUNTRY_53A5
# 10 4
# BRAND_FE66_COUNTRY_D8B0
# 5 4
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 180
# (874, 23)
# select
# train    825
# test      49
# Name: count, dtype: int64
# part 1 done
# BRAND_F148_COUNTRY_D8B0 37 3 34
# BRAND_F148_COUNTRY_3AD0 37 2 35
# BRAND_F148_COUNTRY_3536 36 3 33
# BRAND_F148_COUNTRY_907E 34 1 33
# BRAND_F148_COUNTRY_9891 34 1 33
# BRAND_F148_COUNTRY_C8F4 34 1 33
1
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 207
# (2188, 23)
# select
# train    2124
# test       64
# Name: count, dtype: int64
# part 1 done
# BRAND_0056_COUNTRY_3AD0 60 0 60
# BRAND_0056_COUNTRY_458E 59 0 59
# BRAND_0056_COUNTRY_221C 58 1 57
# BRAND_0056_COUNTRY_0309 58 0 58
# BRAND_0056_COUNTRY_445D 58 0 58
# BRAND_0056_COUNTRY_3F0E 57 1 56
# BRAND_0056_COUNTRY_D5B9 57 0 57
# BRAND_0056_COUNTRY_D8B0 56 0 56
# BRAND_0056_COUNTRY_B835 56 0 56
# BRAND_0056_COUNTRY_89F9 55 3 52
# BRAND_0056_COUNTRY_B6AE 54 1 53
# BRAND_0056_COUNTRY_9891 54 2 52
# BRAND_0056_COUNTRY_A67D 51 2 49
# BRAND_0056_COUNTRY_907E 51 1 50
# BRAND_0056_COUNTRY_C8F4 51 0 51
# BRAND_0056_COUNTRY_88A3 50 1 49
# BRAND_13F8_COUNTRY_907E 50 0 50
# BRAND_0056_COUNTRY_8B47 50 2 48
# BRAND_0056_COUNTRY_8DBB 49 4 45
# BRAND_0056_COUNTRY_77DA 49 1 48
# BRAND_0056_COUNTRY_6B71 48 1 47
# BRAND_0056_COUNTRY_6F78 48 1 47
# BRAND_0056_COUNTRY_5A54 48 0 48
# BRAND_0056_COUNTRY_6C16 47 3 44
# BRAND_0056_COUNTRY_4442 45 2 43
# BRAND_0056_COUNTRY_1007 45 2 43
# BRAND_0056_COUNTRY_2E65 45 2 43
# BRAND_0056_COUNTRY_1033 45 0 45
# BRAND_0056_COUNTRY_9488 45 3 42
# BRAND_BBE0_COUNTRY_7D31 43 1 42
# BRAND_0056_COUNTRY_F78A 42 0 42
# BRAND_0056_COUNTRY_EF33 41 2 39
# BRAND_0056_COUNTRY_0C7D 40 4 36
# BRAND_0056_COUNTRY_4D48 40 1 39
# BRAND_BBE0_COUNTRY_4647 38 3 35
# BRAND_0056_COUNTRY_E319 38 2 36
# BRAND_0056_COUNTRY_06E4 38 1 37
# BRAND_0056_COUNTRY_5180 38 0 38
# BRAND_0056_COUNTRY_C89B 36 3 33
# BRAND_0056_COUNTRY_EA71 36 1 35
# BRAND_0056_COUNTRY_4253 36 0 36
# BRAND_0056_COUNTRY_84C8 35 2 33
# BRAND_0056_COUNTRY_4D5D 33 0 33
# BRAND_0056_COUNTRY_AE54 30 0 30
# BRAND_0056_COUNTRY_C51E 23 3 20
# BRAND_BBE0_COUNTRY_77DA 22 5 17
# BRAND_0056_COUNTRY_FA79 16 3 13
# keep/ignore 47 0
# part 2 done
# ignores done.
# part 3 done
# data size (2124, 23) (64, 23)
# check set()
# lags done.
# after lags (1560, 50)
# check set()
# train data (1560, 46) (1560,)
# iterative fit starts
# BRAND_0056_COUNTRY_06E4
# 26 1
# BRAND_0056_COUNTRY_0C7D
# 28 4
# BRAND_0056_COUNTRY_1007
# 33 2
# BRAND_0056_COUNTRY_221C
# 46 1
# BRAND_0056_COUNTRY_2E65
# 33 2
# BRAND_0056_COUNTRY_3F0E
# 45 1
# BRAND_0056_COUNTRY_4442
# 33 2
# BRAND_0056_COUNTRY_4D48
# 28 1
# BRAND_0056_COUNTRY_6B71
# 36 1
# BRAND_0056_COUNTRY_6C16
# 35 3
# BRAND_0056_COUNTRY_6F78
# 36 1
# BRAND_0056_COUNTRY_77DA
# 37 1
# BRAND_0056_COUNTRY_84C8
# 23 2
# BRAND_0056_COUNTRY_88A3
# 38 1
# BRAND_0056_COUNTRY_89F9
# 43 3
# BRAND_0056_COUNTRY_8B47
# 38 2
# BRAND_0056_COUNTRY_8DBB
# 37 4
# BRAND_0056_COUNTRY_907E
# 39 1
# BRAND_0056_COUNTRY_9488
# 33 3
# BRAND_0056_COUNTRY_9891
# 42 2
# BRAND_0056_COUNTRY_A67D
# 39 2
# BRAND_0056_COUNTRY_B6AE
# 42 1
# BRAND_0056_COUNTRY_C51E
# 11 3
# BRAND_0056_COUNTRY_C89B
# 24 3
# BRAND_0056_COUNTRY_E319
# 26 2
# BRAND_0056_COUNTRY_EA71
# 24 1
# BRAND_0056_COUNTRY_EF33
# 29 2
# BRAND_0056_COUNTRY_FA79
# 4 3
# BRAND_BBE0_COUNTRY_4647
# 26 3
# BRAND_BBE0_COUNTRY_77DA
# 10 5
# BRAND_BBE0_COUNTRY_7D31
# 31 1
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 191
# (306, 23)
# select
# train    280
# test      26
# Name: count, dtype: int64
# part 1 done
# BRAND_267B_COUNTRY_0309 45 2 43
# BRAND_267B_COUNTRY_D8B0 39 2 37
# BRAND_267B_COUNTRY_A67D 38 0 38
# BRAND_267B_COUNTRY_FA79 35 4 31
# BRAND_267B_COUNTRY_89F9 31 0 31
# BRAND_267B_COUNTRY_1007 26 0 26
# BRAND_267B_COUNTRY_4242 25 2 23
# BRAND_267B_COUNTRY_53A5 23 3 20
# BRAND_267B_COUNTRY_907E 8 3 5
# BRAND_267B_COUNTRY_06E4 6 1 5
# BRAND_267B_COUNTRY_5180 4 4 0
# BRAND_267B_COUNTRY_0C7D 0 4 -4
# BRAND_267B_COUNTRY_9488 0 1 -1
# keep/ignore 8 5
# part 2 done
# ignores done.
# part 3 done
# data size (262, 23) (13, 23)
# check set()
# lags done.
# after lags (166, 50)
# check set()
# train data (166, 46) (166,)
# iterative fit starts
# BRAND_267B_COUNTRY_0309
# 33 2
# BRAND_267B_COUNTRY_4242
# 13 2
# BRAND_267B_COUNTRY_53A5
# 11 3
# BRAND_267B_COUNTRY_D8B0
# 27 2
# BRAND_267B_COUNTRY_FA79
# 23 4
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 104
# (316, 23)
# select
# train    307
# test       9
# Name: count, dtype: int64
# part 1 done
# BRAND_4710_COUNTRY_D8B0 60 0 60
# BRAND_4710_COUNTRY_0309 59 1 58
# BRAND_4710_COUNTRY_9891 57 1 56
# BRAND_4710_COUNTRY_89F9 49 2 47
# BRAND_4710_COUNTRY_1007 44 2 42
# BRAND_4710_COUNTRY_EA71 25 3 22
# BRAND_4710_COUNTRY_907E 13 0 13
# keep/ignore 7 0
# part 2 done
# ignores done.
# part 3 done
# data size (307, 23) (9, 23)
# check set()
# lags done.
# after lags (223, 50)
# check set()
# train data (223, 46) (223,)
# iterative fit starts
# BRAND_4710_COUNTRY_0309
# 47 1
# BRAND_4710_COUNTRY_1007
# 32 2
# BRAND_4710_COUNTRY_89F9
# 37 2
# BRAND_4710_COUNTRY_9891
# 45 1
# BRAND_4710_COUNTRY_EA71
# 13 3
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 213
# (323, 23)
# select
# train    298
# test      25
# Name: count, dtype: int64
# part 1 done
# BRAND_014B_COUNTRY_3AD0 29 1 28
# BRAND_014B_COUNTRY_89F9 28 2 26
# BRAND_014B_COUNTRY_9891 27 1 26
# BRAND_014B_COUNTRY_C8F4 25 0 25
# BRAND_014B_COUNTRY_1007 22 1 21
# BRAND_014B_COUNTRY_6B71 20 1 19
# BRAND_014B_COUNTRY_3536 20 3 17
# BRAND_A5D5_COUNTRY_2E65 19 2 17
# BRAND_014B_COUNTRY_88A3 19 0 19
# BRAND_014B_COUNTRY_C89B 11 0 11
# BRAND_014B_COUNTRY_1033 16 1 15
# BRAND_014B_COUNTRY_907E 14 1 13
# BRAND_014B_COUNTRY_E319 13 1 12
# BRAND_014B_COUNTRY_5180 11 1 10
# BRAND_014B_COUNTRY_C51E 10 2 8
# BRAND_014B_COUNTRY_8B47 7 2 5
# BRAND_014B_COUNTRY_EA71 7 3 4
# BRAND_A5D5_COUNTRY_7D31 0 2 -2
# BRAND_014B_COUNTRY_6C16 0 1 -1
# keep/ignore 12 7
# part 2 done
# ignores done.
# part 3 done
# data size (252, 23) (14, 23)
# check set()
# lags done.
# after lags (108, 50)
# check set()
# train data (108, 46) (108,)
# iterative fit starts
# BRAND_014B_COUNTRY_1007
# 10 1
# BRAND_014B_COUNTRY_1033
# 4 1
# BRAND_014B_COUNTRY_3536
# 8 3
# BRAND_014B_COUNTRY_3AD0
# 17 1
# BRAND_014B_COUNTRY_6B71
# 8 1
# BRAND_014B_COUNTRY_89F9
# 16 2
# BRAND_014B_COUNTRY_907E
# 2 1
# BRAND_014B_COUNTRY_9891
# 15 1
# BRAND_014B_COUNTRY_E319
# 1 1
# BRAND_A5D5_COUNTRY_2E65
# 7 2
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 174
# (738, 23)
# select
# train    706
# test      32
# Name: count, dtype: int64
# part 1 done
# BRAND_8808_COUNTRY_D8B0 45 2 43
# BRAND_8808_COUNTRY_A67D 42 1 41
# BRAND_8808_COUNTRY_C8F4 40 4 36
# BRAND_8808_COUNTRY_3AD0 38 1 37
# BRAND_8808_COUNTRY_907E 38 4 34
# BRAND_8808_COUNTRY_89F9 37 1 36
# BRAND_8808_COUNTRY_0309 37 0 37
# BRAND_8808_COUNTRY_4242 36 2 34
# BRAND_8808_COUNTRY_6C16 36 0 36
# BRAND_8808_COUNTRY_06E4 33 1 32
# BRAND_8808_COUNTRY_9891 31 0 31
# BRAND_8808_COUNTRY_53A5 30 0 30
# BRAND_8808_COUNTRY_B6AE 29 0 29
# BRAND_8808_COUNTRY_FA79 29 0 29
# BRAND_8808_COUNTRY_0C7D 28 2 26
# BRAND_8808_COUNTRY_4442 28 2 26
# BRAND_8808_COUNTRY_D5B9 25 2 23
# BRAND_8808_COUNTRY_B835 23 0 23
# BRAND_8808_COUNTRY_5180 23 2 21
# BRAND_8808_COUNTRY_88A3 23 3 20
# BRAND_8808_COUNTRY_4D48 21 1 20
# BRAND_8808_COUNTRY_84C8 20 2 18
# BRAND_8808_COUNTRY_8DBB 8 0 8
# BRAND_8808_COUNTRY_E319 6 2 4
# keep/ignore 22 2
# part 2 done
# ignores done.
# part 3 done
# data size (692, 23) (30, 23)
# check set()
# lags done.
# after lags (428, 50)
# check set()
# train data (428, 46) (428,)
# iterative fit starts
# BRAND_8808_COUNTRY_06E4
# 21 1
# BRAND_8808_COUNTRY_0C7D
# 16 2
# BRAND_8808_COUNTRY_3AD0
# 26 1
# BRAND_8808_COUNTRY_4242
# 24 2
# BRAND_8808_COUNTRY_4442
# 16 2
# BRAND_8808_COUNTRY_4D48
# 9 1
# BRAND_8808_COUNTRY_5180
# 11 2
# BRAND_8808_COUNTRY_84C8
# 8 2
# BRAND_8808_COUNTRY_88A3
# 11 3
# BRAND_8808_COUNTRY_89F9
# 25 1
# BRAND_8808_COUNTRY_907E
# 26 4
# BRAND_8808_COUNTRY_A67D
# 30 1
# BRAND_8808_COUNTRY_C8F4
# 28 4
# BRAND_8808_COUNTRY_D5B9
# 13 2
# BRAND_8808_COUNTRY_D8B0
# 33 2
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 159
# (248, 23)
# select
# train    228
# test      20
# Name: count, dtype: int64
# part 1 done
# BRAND_AA4A_COUNTRY_53A5 26 2 24
# BRAND_AA4A_COUNTRY_445D 20 2 18
# BRAND_6200_COUNTRY_D8B0 19 3 16
# BRAND_6200_COUNTRY_9891 19 0 19
# BRAND_6200_COUNTRY_A67D 14 3 11
# BRAND_6200_COUNTRY_0309 17 2 15
# BRAND_6200_COUNTRY_4242 17 0 17
# BRAND_6200_COUNTRY_89F9 16 1 15
# BRAND_6200_COUNTRY_FA79 15 1 14
# BRAND_6200_COUNTRY_06E4 15 0 15
# BRAND_6200_COUNTRY_C8F4 14 0 14
# BRAND_6200_COUNTRY_5180 12 0 12
# BRAND_6200_COUNTRY_EA71 12 3 9
# BRAND_6200_COUNTRY_221C 9 1 8
# BRAND_E417_COUNTRY_A67D 3 0 3
# BRAND_6200_COUNTRY_9488 0 1 -1
# BRAND_DC2C_COUNTRY_C8F4 0 1 -1
# keep/ignore 11 6
# part 2 done
# ignores done.
# part 3 done
# data size (192, 23) (14, 23)
# check set()
# lags done.
# after lags (60, 50)
# check set()
# train data (60, 46) (60,)
# iterative fit starts
# BRAND_6200_COUNTRY_0309
# 5 2
# BRAND_6200_COUNTRY_89F9
# 4 1
# BRAND_6200_COUNTRY_A67D
# 2 3
# BRAND_6200_COUNTRY_D8B0
# 7 3
# BRAND_6200_COUNTRY_FA79
# 3 1
# BRAND_AA4A_COUNTRY_445D
# 8 2
# BRAND_AA4A_COUNTRY_53A5
# 14 2
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 217
# (363, 23)
# select
# train    340
# test      23
# Name: count, dtype: int64
# part 1 done
# BRAND_CE3C_COUNTRY_445D 47 3 44
# BRAND_CE3C_COUNTRY_D8B0 39 3 36
# BRAND_CE3C_COUNTRY_A67D 30 1 29
# BRAND_CE3C_COUNTRY_53A5 30 2 28
# BRAND_CE3C_COUNTRY_6F78 28 4 24
# BRAND_CE3C_COUNTRY_6C16 28 3 25
# BRAND_CE3C_COUNTRY_3AD0 28 1 27
# BRAND_CE3C_COUNTRY_0309 26 2 24
# BRAND_CE3C_COUNTRY_1007 24 0 24
# BRAND_CE3C_COUNTRY_907E 23 1 22
# BRAND_CE3C_COUNTRY_4242 21 1 20
# BRAND_CE3C_COUNTRY_88A3 16 2 14
# keep/ignore 12 0
# part 2 done
# ignores done.
# part 3 done
# data size (340, 23) (23, 23)
# check set()
# lags done.
# after lags (196, 50)
# check set()
# train data (196, 46) (196,)
# iterative fit starts
# BRAND_CE3C_COUNTRY_0309
# 14 2
# BRAND_CE3C_COUNTRY_3AD0
# 16 1
# BRAND_CE3C_COUNTRY_4242
# 9 1
# BRAND_CE3C_COUNTRY_445D
# 35 3
# BRAND_CE3C_COUNTRY_53A5
# 18 2
# BRAND_CE3C_COUNTRY_6C16
# 16 3
# BRAND_CE3C_COUNTRY_6F78
# 16 4
# BRAND_CE3C_COUNTRY_88A3
# 4 2
# BRAND_CE3C_COUNTRY_907E
# 11 1
# BRAND_CE3C_COUNTRY_A67D
# 18 1
# BRAND_CE3C_COUNTRY_D8B0
# 27 3
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 118
# (293, 23)
# select
# train    284
# test       9
# Name: count, dtype: int64
# part 1 done
# BRAND_C367_COUNTRY_89F9 41 1 40
# BRAND_C367_COUNTRY_9891 40 1 39
# BRAND_C367_COUNTRY_D8B0 39 3 36
# BRAND_C367_COUNTRY_4242 37 2 35
# BRAND_C367_COUNTRY_D5B9 33 0 33
# BRAND_C367_COUNTRY_907E 28 1 27
# BRAND_C367_COUNTRY_6C16 24 1 23
# BRAND_C367_COUNTRY_3AD0 21 0 21
# BRAND_C367_COUNTRY_1007 21 0 21
# keep/ignore 9 0
# part 2 done
# ignores done.
# part 3 done
# data size (284, 23) (9, 23)
# check set()
# lags done.
# after lags (176, 50)
# check set()
# train data (176, 46) (176,)
# iterative fit starts
# BRAND_C367_COUNTRY_4242
# 25 2
# BRAND_C367_COUNTRY_6C16
# 12 1
# BRAND_C367_COUNTRY_89F9
# 29 1
# BRAND_C367_COUNTRY_907E
# 16 1
# BRAND_C367_COUNTRY_9891
# 28 1
# BRAND_C367_COUNTRY_D8B0
# 27 3
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 95
# (868, 23)
# select
# train    832
# test      36
# Name: count, dtype: int64
# part 1 done
# BRAND_C114_COUNTRY_53A5 60 0 60
# BRAND_C114_COUNTRY_3AD0 47 0 47
# BRAND_BCB1_COUNTRY_445D 47 2 45
# BRAND_C114_COUNTRY_A67D 29 1 28
# BRAND_C114_COUNTRY_9891 45 2 43
# BRAND_C114_COUNTRY_C8F4 45 0 45
# BRAND_C114_COUNTRY_4242 44 2 42
# BRAND_C114_COUNTRY_D8B0 43 2 41
# BRAND_C114_COUNTRY_FA79 42 2 40
# BRAND_C114_COUNTRY_D5B9 41 1 40
# BRAND_C114_COUNTRY_89F9 40 2 38
# BRAND_C114_COUNTRY_4D48 39 1 38
# BRAND_E425_COUNTRY_D8B0 1 0 1
# BRAND_C114_COUNTRY_EA71 36 2 34
# BRAND_C114_COUNTRY_221C 35 0 35
# BRAND_C114_COUNTRY_907E 34 4 30
# BRAND_C114_COUNTRY_0309 29 1 28
# BRAND_C114_COUNTRY_1007 29 0 29
# BRAND_C114_COUNTRY_C51E 27 2 25
# BRAND_C114_COUNTRY_88A3 20 1 19
# BRAND_C114_COUNTRY_4253 20 2 18
# BRAND_D571_COUNTRY_A67D 16 0 16
# BRAND_C114_COUNTRY_5FEB 16 1 15
# BRAND_C114_COUNTRY_9488 15 3 12
# BRAND_C114_COUNTRY_B6AE 13 3 10
# BRAND_C114_COUNTRY_AE54 13 2 11
# BRAND_C114_COUNTRY_8DBB 6 0 6
# keep/ignore 25 2
# part 2 done
# ignores done.
# part 3 done
# data size (825, 23) (36, 23)
# check set()
# lags done.
# after lags (525, 50)
# check set()
# train data (525, 46) (525,)
# iterative fit starts
# BRAND_BCB1_COUNTRY_445D
# 35 2
# BRAND_C114_COUNTRY_0309
# 17 1
# BRAND_C114_COUNTRY_4242
# 32 2
# BRAND_C114_COUNTRY_4253
# 8 2
# BRAND_C114_COUNTRY_4D48
# 27 1
# BRAND_C114_COUNTRY_5FEB
# 4 1
# BRAND_C114_COUNTRY_88A3
# 8 1
# BRAND_C114_COUNTRY_89F9
# 28 2
# BRAND_C114_COUNTRY_907E
# 22 4
# BRAND_C114_COUNTRY_9488
# 3 3
# BRAND_C114_COUNTRY_9891
# 33 2
# BRAND_C114_COUNTRY_A67D
# 17 1
# BRAND_C114_COUNTRY_AE54
# 1 2
# BRAND_C114_COUNTRY_B6AE
# 1 3
# BRAND_C114_COUNTRY_C51E
# 15 2
# BRAND_C114_COUNTRY_D5B9
# 29 1
# BRAND_C114_COUNTRY_D8B0
# 31 2
# BRAND_C114_COUNTRY_EA71
# 24 2
# BRAND_C114_COUNTRY_FA79
# 30 2
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 49
# (724, 23)
# select
# train    704
# test      20
# Name: count, dtype: int64
# part 1 done
# BRAND_60F2_COUNTRY_D8B0 60 0 60
# BRAND_60F2_COUNTRY_D5B9 60 0 60
# BRAND_60F2_COUNTRY_445D 57 0 57
# BRAND_60F2_COUNTRY_53A5 55 2 53
# BRAND_60F2_COUNTRY_907E 54 1 53
# BRAND_60F2_COUNTRY_9488 54 1 53
# BRAND_60F2_COUNTRY_4242 53 0 53
# BRAND_60F2_COUNTRY_8DBB 50 1 49
# BRAND_60F2_COUNTRY_FA79 47 2 45
# BRAND_60F2_COUNTRY_1007 45 2 43
# BRAND_60F2_COUNTRY_6C16 44 2 42
# BRAND_60F2_COUNTRY_6F78 43 3 40
# BRAND_60F2_COUNTRY_E319 31 2 29
# BRAND_60F2_COUNTRY_B6AE 29 3 26
# BRAND_60F2_COUNTRY_0309 22 0 22
# BRAND_60F2_COUNTRY_C89B 0 1 -1
# keep/ignore 15 1
# part 2 done
# ignores done.
# part 3 done
# data size (704, 23) (19, 23)
# check set()
# lags done.
# after lags (524, 50)
# check set()
# train data (524, 46) (524,)
# iterative fit starts
# BRAND_60F2_COUNTRY_1007
# 33 2
# BRAND_60F2_COUNTRY_53A5
# 43 2
# BRAND_60F2_COUNTRY_6C16
# 32 2
# BRAND_60F2_COUNTRY_6F78
# 31 3
# BRAND_60F2_COUNTRY_8DBB
# 38 1
# BRAND_60F2_COUNTRY_907E
# 42 1
# BRAND_60F2_COUNTRY_9488
# 42 1
# BRAND_60F2_COUNTRY_B6AE
# 17 3
# BRAND_60F2_COUNTRY_E319
# 19 2
# BRAND_60F2_COUNTRY_FA79
# 35 2
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 167
# (899, 23)
# select
# train    879
# test      20
# Name: count, dtype: int64
# part 1 done
# BRAND_B1E8_COUNTRY_A67D 49 1 48
# BRAND_B1E8_COUNTRY_445D 47 0 47
# BRAND_B1E8_COUNTRY_9891 47 1 46
# BRAND_B1E8_COUNTRY_06E4 47 0 47
# BRAND_B1E8_COUNTRY_4442 47 3 44
# BRAND_B1E8_COUNTRY_53A5 47 1 46
# BRAND_B1E8_COUNTRY_0309 47 0 47
# BRAND_B1E8_COUNTRY_6F78 46 1 45
# BRAND_B1E8_COUNTRY_4242 45 3 42
# BRAND_B1E8_COUNTRY_D8B0 45 1 44
# BRAND_B1E8_COUNTRY_3AD0 44 0 44
# BRAND_B1E8_COUNTRY_88A3 43 0 43
# BRAND_B1E8_COUNTRY_6C16 43 0 43
# BRAND_B1E8_COUNTRY_B6AE 42 2 40
# BRAND_B1E8_COUNTRY_907E 41 0 41
# BRAND_B1E8_COUNTRY_0C7D 37 1 36
# BRAND_B1E8_COUNTRY_1007 37 2 35
# BRAND_B1E8_COUNTRY_FA79 37 1 36
# BRAND_B1E8_COUNTRY_4253 28 1 27
# BRAND_B1E8_COUNTRY_B835 25 0 25
# BRAND_B1E8_COUNTRY_8DBB 19 0 19
# BRAND_8D65_COUNTRY_221C 16 2 14
# keep/ignore 22 0
# part 2 done
# ignores done.
# part 3 done
# data size (879, 23) (20, 23)
# check set()
# lags done.
# after lags (615, 50)
# check set()
# train data (615, 46) (615,)
# iterative fit starts
# BRAND_8D65_COUNTRY_221C
# 4 2
# BRAND_B1E8_COUNTRY_0C7D
# 25 1
# BRAND_B1E8_COUNTRY_1007
# 25 2
# BRAND_B1E8_COUNTRY_4242
# 33 3
# BRAND_B1E8_COUNTRY_4253
# 16 1
# BRAND_B1E8_COUNTRY_4442
# 35 3
# BRAND_B1E8_COUNTRY_53A5
# 35 1
# BRAND_B1E8_COUNTRY_6F78
# 34 1
# BRAND_B1E8_COUNTRY_9891
# 35 1
# BRAND_B1E8_COUNTRY_A67D
# 37 1
# BRAND_B1E8_COUNTRY_B6AE
# 30 2
# BRAND_B1E8_COUNTRY_D8B0
# 33 1
# BRAND_B1E8_COUNTRY_FA79
# 25 1
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 40
# (1007, 23)
# select
# train    985
# test      22
# Name: count, dtype: int64
# part 1 done
# BRAND_8D59_COUNTRY_C8F4 59 1 58
# BRAND_8D59_COUNTRY_D8B0 59 0 59
# BRAND_8D59_COUNTRY_6F78 57 0 57
# BRAND_8D59_COUNTRY_9891 56 3 53
# BRAND_8D59_COUNTRY_A67D 56 0 56
# BRAND_8D59_COUNTRY_3AD0 55 1 54
# BRAND_8D59_COUNTRY_D5B9 54 1 53
# BRAND_8D59_COUNTRY_53A5 54 4 50
# BRAND_8D59_COUNTRY_4242 52 2 50
# BRAND_8D59_COUNTRY_445D 51 1 50
# BRAND_8D59_COUNTRY_6C16 46 1 45
# BRAND_8D59_COUNTRY_4442 47 1 46
# BRAND_8D59_COUNTRY_89F9 45 0 45
# BRAND_8D59_COUNTRY_907E 44 2 42
# BRAND_8D59_COUNTRY_B6AE 43 1 42
# BRAND_8D59_COUNTRY_FA79 38 0 38
# BRAND_8D59_COUNTRY_0309 37 0 37
# BRAND_8D59_COUNTRY_B835 31 1 30
# BRAND_8D59_COUNTRY_06E4 29 1 28
# BRAND_8D59_COUNTRY_88A3 29 0 29
# BRAND_27C0_COUNTRY_6C16 4 0 4
# BRAND_8D59_COUNTRY_221C 15 1 14
# BRAND_8D59_COUNTRY_8DBB 14 0 14
# BRAND_8D59_COUNTRY_C51E 10 1 9
# keep/ignore 22 2
# part 2 done
# ignores done.
# part 3 done
# data size (971, 23) (21, 23)
# check set()
# lags done.
# after lags (707, 50)
# check set()
# train data (707, 46) (707,)
# iterative fit starts
# BRAND_8D59_COUNTRY_06E4
# 17 1
# BRAND_8D59_COUNTRY_221C
# 3 1
# BRAND_8D59_COUNTRY_3AD0
# 43 1
# BRAND_8D59_COUNTRY_4242
# 40 2
# BRAND_8D59_COUNTRY_4442
# 35 1
# BRAND_8D59_COUNTRY_445D
# 39 1
# BRAND_8D59_COUNTRY_53A5
# 42 4
# BRAND_8D59_COUNTRY_6C16
# 34 1
# BRAND_8D59_COUNTRY_907E
# 32 2
# BRAND_8D59_COUNTRY_9891
# 44 3
# BRAND_8D59_COUNTRY_B6AE
# 31 1
# BRAND_8D59_COUNTRY_B835
# 19 1
# BRAND_8D59_COUNTRY_C8F4
# 47 1
# BRAND_8D59_COUNTRY_D5B9
# 42 1
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 85
# (14, 23)
# select
# train    11
# test      3
# Name: count, dtype: int64
# part 1 done
# BRAND_DE7F_COUNTRY_53A5 11 3 8
# keep/ignore 0 1
# part 2 done
# ignores done.
# part 3 done
# skip next
# ---------------------------------------
# drug_id 73
# (953, 23)
# select
# train    941
# test      12
# Name: count, dtype: int64
# part 1 done
# BRAND_061C_COUNTRY_6F78 60 0 60
# BRAND_061C_COUNTRY_1007 60 0 60
# BRAND_061C_COUNTRY_C8F4 60 0 60
# BRAND_061C_COUNTRY_88A3 60 0 60
# BRAND_061C_COUNTRY_9488 60 0 60
# BRAND_061C_COUNTRY_89F9 60 0 60
# BRAND_061C_COUNTRY_D5B9 60 0 60
# BRAND_061C_COUNTRY_A67D 49 0 49
# BRAND_061C_COUNTRY_907E 60 0 60
# BRAND_8EAE_COUNTRY_8DBB 60 0 60
# BRAND_061C_COUNTRY_0C7D 60 0 60
# BRAND_061C_COUNTRY_445D 59 0 59
# BRAND_39DA_COUNTRY_A67D 7 0 7
# BRAND_5F45_COUNTRY_5180 49 1 48
# BRAND_061C_COUNTRY_6B71 45 2 43
# BRAND_061C_COUNTRY_0309 44 2 42
# BRAND_061C_COUNTRY_B6AE 36 1 35
# BRAND_061C_COUNTRY_C51E 32 1 31
# BRAND_8E05_COUNTRY_A67D 2 0 2
# BRAND_061C_COUNTRY_221C 16 5 11
# BRAND_4290_COUNTRY_A67D 2 0 2
# keep/ignore 18 3
# part 2 done
# ignores done.
# part 3 done
# data size (930, 23) (12, 23)
# check set()
# lags done.
# after lags (714, 50)
# check set()
# train data (714, 46) (714,)
# iterative fit starts
# BRAND_061C_COUNTRY_0309
# 32 2
# BRAND_061C_COUNTRY_221C
# 4 5
# BRAND_061C_COUNTRY_6B71
# 33 2
# BRAND_061C_COUNTRY_B6AE
# 24 1
# BRAND_061C_COUNTRY_C51E
# 20 1
# BRAND_5F45_COUNTRY_5180
# 37 1
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 79
# (623, 23)
# select
# train    592
# test      31
# Name: count, dtype: int64
# part 1 done
# BRAND_A368_COUNTRY_6B71 60 0 60
# BRAND_9D27_COUNTRY_D8B0 49 0 49
# BRAND_8DD7_COUNTRY_C89B 40 0 40
# BRAND_CF50_COUNTRY_D8B0 7 0 7
# BRAND_4888_COUNTRY_4242 33 3 30
# BRAND_4888_COUNTRY_D5B9 32 2 30
# BRAND_CF50_COUNTRY_89F9 32 3 29
# BRAND_4888_COUNTRY_C8F4 32 1 31
# BRAND_CF50_COUNTRY_8DBB 31 2 29
# BRAND_4888_COUNTRY_6F78 30 1 29
# BRAND_A550_COUNTRY_D8B0 4 0 4
# BRAND_4888_COUNTRY_6C16 28 2 26
# BRAND_4888_COUNTRY_9891 28 0 28
# BRAND_4888_COUNTRY_0309 19 3 16
# BRAND_4888_COUNTRY_3AD0 24 1 23
# BRAND_4888_COUNTRY_907E 21 4 17
# BRAND_6C97_COUNTRY_0309 8 0 8
# BRAND_9873_COUNTRY_53A5 20 1 19
# BRAND_4888_COUNTRY_5180 19 0 19
# BRAND_4888_COUNTRY_88A3 19 0 19
# BRAND_4888_COUNTRY_3536 17 1 16
# BRAND_4888_COUNTRY_2E65 17 4 13
# BRAND_4888_COUNTRY_B6AE 15 1 14
# BRAND_CF50_COUNTRY_4253 5 1 4
# BRAND_E9FD_COUNTRY_4253 2 0 2
# BRAND_4888_COUNTRY_AE54 0 1 -1
# keep/ignore 20 6
# part 2 done
# ignores done.
# part 3 done
# data size (566, 23) (29, 23)
# check set()
# lags done.
# after lags (326, 50)
# check set()
# train data (326, 46) (326,)
# iterative fit starts
# BRAND_4888_COUNTRY_0309
# 7 3
# BRAND_4888_COUNTRY_2E65
# 5 4
# BRAND_4888_COUNTRY_3536
# 5 1
# BRAND_4888_COUNTRY_3AD0
# 12 1
# BRAND_4888_COUNTRY_4242
# 21 3
# BRAND_4888_COUNTRY_6C16
# 16 2
# BRAND_4888_COUNTRY_6F78
# 18 1
# BRAND_4888_COUNTRY_907E
# 9 4
# BRAND_4888_COUNTRY_B6AE
# 3 1
# BRAND_4888_COUNTRY_C8F4
# 20 1
# BRAND_4888_COUNTRY_D5B9
# 20 2
# BRAND_9873_COUNTRY_53A5
# 8 1
# BRAND_CF50_COUNTRY_89F9
# 20 3
# BRAND_CF50_COUNTRY_8DBB
# 19 2
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 29
# (172, 23)
# select
# train    163
# test       9
# Name: count, dtype: int64
# part 1 done
# BRAND_19C4_COUNTRY_0309 31 3 28
# BRAND_19C4_COUNTRY_C8F4 25 1 24
# BRAND_19C4_COUNTRY_A67D 24 1 23
# BRAND_19C4_COUNTRY_9891 24 0 24
# BRAND_19C4_COUNTRY_89F9 23 0 23
# BRAND_19C4_COUNTRY_4D48 19 2 17
# BRAND_19C4_COUNTRY_4242 17 2 15
# keep/ignore 7 0
# part 2 done
# ignores done.
# part 3 done
# data size (163, 23) (9, 23)
# check set()
# lags done.
# after lags (79, 50)
# check set()
# train data (79, 46) (79,)
# iterative fit starts
# BRAND_19C4_COUNTRY_0309
# 19 3
# BRAND_19C4_COUNTRY_4242
# 5 2
# BRAND_19C4_COUNTRY_4D48
# 7 2
# BRAND_19C4_COUNTRY_A67D
# 12 1
# BRAND_19C4_COUNTRY_C8F4
# 13 1
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 112
# (464, 23)
# select
# train    453
# test      11
# Name: count, dtype: int64
# part 1 done
# BRAND_6CC4_COUNTRY_8DBB 60 0 60
# BRAND_6CC4_COUNTRY_D8B0 60 0 60
# BRAND_6CC4_COUNTRY_0309 58 0 58
# BRAND_6CC4_COUNTRY_89F9 58 0 58
# BRAND_6CC4_COUNTRY_3AD0 46 3 43
# BRAND_6CC4_COUNTRY_1007 44 3 41
# BRAND_6CC4_COUNTRY_4253 40 4 36
# BRAND_6CC4_COUNTRY_6F78 23 0 23
# BRAND_6CC4_COUNTRY_221C 28 0 28
# BRAND_6CC4_COUNTRY_53A5 26 1 25
# BRAND_1590_COUNTRY_6F78 4 0 4
# BRAND_4F4D_COUNTRY_6F78 5 0 5
# BRAND_B9D7_COUNTRY_6F78 1 0 1
# keep/ignore 10 3
# part 2 done
# ignores done.
# part 3 done
# data size (443, 23) (11, 23)
# check set()
# lags done.
# after lags (323, 50)
# check set()
# train data (323, 46) (323,)
# iterative fit starts
# BRAND_6CC4_COUNTRY_1007
# 32 3
# BRAND_6CC4_COUNTRY_3AD0
# 34 3
# BRAND_6CC4_COUNTRY_4253
# 28 4
# BRAND_6CC4_COUNTRY_53A5
# 14 1
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 58
# (260, 23)
# select
# train    246
# test      14
# Name: count, dtype: int64
# part 1 done
# BRAND_ACB5_COUNTRY_D8B0 31 1 30
# BRAND_ACB5_COUNTRY_3AD0 24 0 24
# BRAND_ACB5_COUNTRY_1007 24 2 22
# BRAND_ACB5_COUNTRY_4242 23 1 22
# BRAND_ACB5_COUNTRY_88A3 23 1 22
# BRAND_ACB5_COUNTRY_5180 20 2 18
# BRAND_ACB5_COUNTRY_89F9 17 0 17
# BRAND_ACB5_COUNTRY_6F78 17 0 17
# BRAND_ACB5_COUNTRY_907E 16 1 15
# BRAND_ACB5_COUNTRY_06E4 15 1 14
# BRAND_ACB5_COUNTRY_0C7D 15 3 12
# BRAND_ACB5_COUNTRY_5FEB 11 0 11
# BRAND_ACB5_COUNTRY_D5B9 10 2 8
# keep/ignore 11 2
# part 2 done
# ignores done.
# part 3 done
# data size (225, 23) (12, 23)
# check set()
# lags done.
# after lags (93, 50)
# check set()
# train data (93, 46) (93,)
# iterative fit starts
# BRAND_ACB5_COUNTRY_06E4
# 3 1
# BRAND_ACB5_COUNTRY_0C7D
# 3 3
# BRAND_ACB5_COUNTRY_1007
# 12 2
# BRAND_ACB5_COUNTRY_4242
# 11 1
# BRAND_ACB5_COUNTRY_5180
# 8 2
# BRAND_ACB5_COUNTRY_88A3
# 11 1
# BRAND_ACB5_COUNTRY_907E
# 4 1
# BRAND_ACB5_COUNTRY_D8B0
# 19 1
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 223
# (236, 23)
# select
# train    212
# test      24
# Name: count, dtype: int64
# part 1 done
# BRAND_56A9_COUNTRY_D8B0 27 3 24
# BRAND_56A9_COUNTRY_9891 22 1 21
# BRAND_56A9_COUNTRY_A67D 22 3 19
# BRAND_56A9_COUNTRY_89F9 20 0 20
# BRAND_56A9_COUNTRY_4242 20 2 18
# BRAND_56A9_COUNTRY_53A5 20 0 20
# BRAND_56A9_COUNTRY_0309 17 5 12
# BRAND_56A9_COUNTRY_06E4 17 1 16
# BRAND_56A9_COUNTRY_6F78 16 3 13
# BRAND_56A9_COUNTRY_3AD0 13 3 10
# BRAND_56A9_COUNTRY_907E 12 3 9
# BRAND_D1F8_COUNTRY_9891 3 0 3
# BRAND_56A9_COUNTRY_9488 3 0 3
# keep/ignore 10 3
# part 2 done
# ignores done.
# part 3 done
# data size (194, 23) (21, 23)
# check set()
# lags done.
# after lags (74, 50)
# check set()
# train data (74, 46) (74,)
# iterative fit starts
# BRAND_56A9_COUNTRY_0309
# 5 5
# BRAND_56A9_COUNTRY_06E4
# 5 1
# BRAND_56A9_COUNTRY_3AD0
# 1 3
# BRAND_56A9_COUNTRY_4242
# 8 2
# BRAND_56A9_COUNTRY_6F78
# 4 3
# BRAND_56A9_COUNTRY_9891
# 10 1
# BRAND_56A9_COUNTRY_A67D
# 10 3
# BRAND_56A9_COUNTRY_D8B0
# 15 3
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 66
# (1349, 23)
# select
# train    1332
# test       17
# Name: count, dtype: int64
# part 1 done
# BRAND_F05A_COUNTRY_3AD0 60 0 60
# BRAND_AAD2_COUNTRY_4242 16 0 16
# BRAND_8A81_COUNTRY_4242 23 0 23
# BRAND_8E44_COUNTRY_4242 17 0 17
# BRAND_F05A_COUNTRY_89F9 60 0 60
# BRAND_D9B8_COUNTRY_3536 60 0 60
# BRAND_F05A_COUNTRY_88A3 60 0 60
# BRAND_F05A_COUNTRY_6B71 60 0 60
# BRAND_F05A_COUNTRY_4253 60 0 60
# BRAND_F05A_COUNTRY_1007 60 0 60
# BRAND_F05A_COUNTRY_B6AE 60 0 60
# BRAND_F05A_COUNTRY_EF33 60 0 60
# BRAND_F05A_COUNTRY_5FEB 60 0 60
# BRAND_F05A_COUNTRY_2E65 60 0 60
# BRAND_5540_COUNTRY_4D48 60 0 60
# BRAND_F05A_COUNTRY_907E 60 0 60
# BRAND_F05A_COUNTRY_D5B9 58 0 58
# BRAND_F05A_COUNTRY_06E4 57 1 56
# BRAND_F05A_COUNTRY_84C8 55 0 55
# BRAND_F05A_COUNTRY_E319 53 1 52
# BRAND_F05A_COUNTRY_B835 51 4 47
# BRAND_F05A_COUNTRY_FA79 37 0 37
# BRAND_5BAE_COUNTRY_4242 2 0 2
# BRAND_F05A_COUNTRY_445D 34 1 33
# BRAND_F05A_COUNTRY_C89B 32 1 31
# BRAND_F05A_COUNTRY_0309 32 3 29
# BRAND_4D32_COUNTRY_4242 2 0 2
# BRAND_F05A_COUNTRY_5180 24 3 21
# BRAND_F05A_COUNTRY_6C16 20 0 20
# BRAND_F05A_COUNTRY_9488 20 1 19
# BRAND_F05A_COUNTRY_AE54 11 1 10
# BRAND_F05A_COUNTRY_0C7D 8 1 7
# keep/ignore 28 4
# part 2 done
# ignores done.
# part 3 done
# data size (1309, 23) (15, 23)
# check set()
# lags done.
# after lags (973, 50)
# check set()
# train data (973, 46) (973,)
# iterative fit starts
# BRAND_F05A_COUNTRY_0309
# 20 3
# BRAND_F05A_COUNTRY_06E4
# 45 1
# BRAND_F05A_COUNTRY_445D
# 22 1
# BRAND_F05A_COUNTRY_5180
# 12 3
# BRAND_F05A_COUNTRY_9488
# 8 1
# BRAND_F05A_COUNTRY_B835
# 39 4
# BRAND_F05A_COUNTRY_C89B
# 20 1
# BRAND_F05A_COUNTRY_E319
# 41 1
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 123
# (500, 23)
# select
# train    474
# test      26
# Name: count, dtype: int64
# part 1 done
# BRAND_BDB6_COUNTRY_445D 36 1 35
# BRAND_BDB6_COUNTRY_D8B0 37 3 34
# BRAND_BDB6_COUNTRY_4242 35 0 35
# BRAND_BDB6_COUNTRY_53A5 31 3 28
# BRAND_BDB6_COUNTRY_06E4 31 2 29
# BRAND_BDB6_COUNTRY_A67D 30 1 29
# BRAND_BDB6_COUNTRY_6C16 30 0 30
# BRAND_BDB6_COUNTRY_C8F4 27 3 24
# BRAND_BDB6_COUNTRY_3AD0 25 2 23
# BRAND_BDB6_COUNTRY_B6AE 24 0 24
# BRAND_BDB6_COUNTRY_0309 23 1 22
# BRAND_BDB6_COUNTRY_4442 23 1 22
# BRAND_BDB6_COUNTRY_1007 22 1 21
# BRAND_BDB6_COUNTRY_907E 22 2 20
# BRAND_BDB6_COUNTRY_9891 22 2 20
# BRAND_BDB6_COUNTRY_4253 21 0 21
# BRAND_BDB6_COUNTRY_88A3 21 0 21
# BRAND_34F9_COUNTRY_445D 1 0 1
# BRAND_BDB6_COUNTRY_8DBB 7 0 7
# BRAND_BDB6_COUNTRY_FA79 6 2 4
# BRAND_BDB6_COUNTRY_5FEB 0 2 -2
# keep/ignore 17 4
# part 2 done
# ignores done.
# part 3 done
# data size (460, 23) (22, 23)
# check set()
# lags done.
# after lags (256, 50)
# check set()
# train data (256, 46) (256,)
# iterative fit starts
# BRAND_BDB6_COUNTRY_0309
# 11 1
# BRAND_BDB6_COUNTRY_06E4
# 19 2
# BRAND_BDB6_COUNTRY_1007
# 10 1
# BRAND_BDB6_COUNTRY_3AD0
# 13 2
# BRAND_BDB6_COUNTRY_4442
# 11 1
# BRAND_BDB6_COUNTRY_445D
# 24 1
# BRAND_BDB6_COUNTRY_53A5
# 19 3
# BRAND_BDB6_COUNTRY_907E
# 10 2
# BRAND_BDB6_COUNTRY_9891
# 10 2
# BRAND_BDB6_COUNTRY_A67D
# 18 1
# BRAND_BDB6_COUNTRY_C8F4
# 15 3
# BRAND_BDB6_COUNTRY_D8B0
# 25 3
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 1
# (357, 23)
# select
# train    346
# test      11
# Name: count, dtype: int64
# part 1 done
# BRAND_F062_COUNTRY_D8B0 60 0 60
# BRAND_FEAA_COUNTRY_4242 60 0 60
# BRAND_FEAA_COUNTRY_1007 58 1 57
# BRAND_FEAA_COUNTRY_9891 54 2 52
# BRAND_FEAA_COUNTRY_0309 42 3 39
# BRAND_FEAA_COUNTRY_907E 35 3 32
# BRAND_FEAA_COUNTRY_4253 27 1 26
# BRAND_FEAA_COUNTRY_B6AE 10 1 9
# keep/ignore 7 1
# part 2 done
# ignores done.
# part 3 done
# data size (336, 23) (10, 23)
# check set()
# lags done.
# after lags (252, 50)
# check set()
# train data (252, 46) (252,)
# iterative fit starts
# BRAND_FEAA_COUNTRY_0309
# 30 3
# BRAND_FEAA_COUNTRY_1007
# 46 1
# BRAND_FEAA_COUNTRY_4253
# 15 1
# BRAND_FEAA_COUNTRY_907E
# 23 3
# BRAND_FEAA_COUNTRY_9891
# 42 2
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 14
# (42, 23)
# select
# train    30
# test     12
# Name: count, dtype: int64
# part 1 done
# BRAND_9259_COUNTRY_D8B0 8 2 6
# BRAND_9259_COUNTRY_B835 5 1 4
# BRAND_9259_COUNTRY_9891 4 0 4
# BRAND_9259_COUNTRY_445D 4 0 4
# BRAND_9259_COUNTRY_C8F4 3 2 1
# BRAND_9259_COUNTRY_4442 2 1 1
# BRAND_9259_COUNTRY_53A5 2 0 2
# BRAND_9259_COUNTRY_3AD0 1 1 0
# BRAND_9259_COUNTRY_AE54 1 1 0
# BRAND_9259_COUNTRY_A67D 0 1 -1
# BRAND_9259_COUNTRY_1007 0 1 -1
# BRAND_9259_COUNTRY_4242 0 1 -1
# BRAND_9259_COUNTRY_5180 0 1 -1
# keep/ignore 0 13
# part 2 done
# ignores done.
# part 3 done
# skip next
# ---------------------------------------
# drug_id 64
# (1070, 23)
# select
# train    1043
# test       27
# Name: count, dtype: int64
# part 1 done
# BRAND_58DC_COUNTRY_C8F4 60 0 60
# BRAND_58DC_COUNTRY_3AD0 60 0 60
# BRAND_58DC_COUNTRY_A67D 60 0 60
# BRAND_58DC_COUNTRY_EA71 58 0 58
# BRAND_58DC_COUNTRY_907E 57 1 56
# BRAND_58DC_COUNTRY_88A3 56 1 55
# BRAND_58DC_COUNTRY_53A5 56 0 56
# BRAND_58DC_COUNTRY_3536 54 0 54
# BRAND_58DC_COUNTRY_89F9 54 0 54
# BRAND_58DC_COUNTRY_6B71 52 1 51
# BRAND_58DC_COUNTRY_6C16 48 2 46
# BRAND_58DC_COUNTRY_9488 47 0 47
# BRAND_58DC_COUNTRY_1007 47 3 44
# BRAND_58DC_COUNTRY_221C 46 2 44
# BRAND_58DC_COUNTRY_8DBB 43 2 41
# BRAND_58DC_COUNTRY_8B47 41 3 38
# BRAND_58DC_COUNTRY_EF33 40 1 39
# BRAND_58DC_COUNTRY_4253 39 1 38
# BRAND_58DC_COUNTRY_4D48 36 1 35
# BRAND_58DC_COUNTRY_5180 35 1 34
# BRAND_58DC_COUNTRY_1033 28 3 25
# BRAND_797D_COUNTRY_C89B 15 2 13
# BRAND_797D_COUNTRY_7D31 8 3 5
# BRAND_58DC_COUNTRY_AE54 3 0 3
# keep/ignore 22 2
# part 2 done
# ignores done.
# part 3 done
# data size (1032, 23) (24, 23)
# check set()
# lags done.
# after lags (768, 50)
# check set()
# train data (768, 46) (768,)
# iterative fit starts
# BRAND_58DC_COUNTRY_1007
# 35 3
# BRAND_58DC_COUNTRY_1033
# 16 3
# BRAND_58DC_COUNTRY_221C
# 34 2
# BRAND_58DC_COUNTRY_4253
# 27 1
# BRAND_58DC_COUNTRY_4D48
# 24 1
# BRAND_58DC_COUNTRY_5180
# 23 1
# BRAND_58DC_COUNTRY_6B71
# 40 1
# BRAND_58DC_COUNTRY_6C16
# 36 2
# BRAND_58DC_COUNTRY_88A3
# 44 1
# BRAND_58DC_COUNTRY_8B47
# 29 3
# BRAND_58DC_COUNTRY_8DBB
# 31 2
# BRAND_58DC_COUNTRY_907E
# 45 1
# BRAND_58DC_COUNTRY_EF33
# 28 1
# BRAND_797D_COUNTRY_C89B
# 3 2
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 218
# (342, 23)
# select
# train    339
# test       3
# Name: count, dtype: int64
# part 1 done
# BRAND_C21A_COUNTRY_B6AE 60 0 60
# BRAND_C21A_COUNTRY_4442 60 0 60
# BRAND_C21A_COUNTRY_6B71 60 0 60
# BRAND_B5CF_COUNTRY_5FEB 60 0 60
# BRAND_E68F_COUNTRY_AE54 39 0 39
# BRAND_C21A_COUNTRY_E319 30 0 30
# BRAND_C21A_COUNTRY_C89B 22 1 21
# BRAND_C21A_COUNTRY_0C7D 8 2 6
# keep/ignore 7 1
# part 2 done
# ignores done.
# part 3 done
# data size (331, 23) (1, 23)
# check set()
# lags done.
# after lags (247, 50)
# check set()
# train data (247, 46) (247,)
# iterative fit starts
# BRAND_C21A_COUNTRY_C89B
# 10 1
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 9
# (75, 23)
# select
# train    57
# test     18
# Name: count, dtype: int64
# part 1 done
# BRAND_C352_COUNTRY_3AD0 11 3 8
# BRAND_C352_COUNTRY_D8B0 10 2 8
# BRAND_C352_COUNTRY_9891 9 2 7
# BRAND_C352_COUNTRY_53A5 8 2 6
# BRAND_C352_COUNTRY_6C16 4 0 4
# BRAND_C352_COUNTRY_5180 4 1 3
# BRAND_C352_COUNTRY_A67D 4 1 3
# BRAND_D72F_COUNTRY_3F0E 3 1 2
# BRAND_D72F_COUNTRY_7D31 2 2 0
# BRAND_C352_COUNTRY_89F9 2 0 2
# BRAND_C352_COUNTRY_5A54 0 1 -1
# BRAND_D72F_COUNTRY_1033 0 2 -2
# BRAND_C352_COUNTRY_C8F4 0 1 -1
# keep/ignore 0 13
# part 2 done
# ignores done.
# part 3 done
# skip next
# ---------------------------------------
# drug_id 179
# (1571, 23)
# select
# train    1554
# test       17
# Name: count, dtype: int64
# part 1 done
# BRAND_A465_COUNTRY_D8B0 52 0 52
# BRAND_229A_COUNTRY_4242 57 0 57
# BRAND_E7DC_COUNTRY_445D 60 0 60
# BRAND_229A_COUNTRY_FA79 60 0 60
# BRAND_229A_COUNTRY_D5B9 60 0 60
# BRAND_229A_COUNTRY_06E4 60 0 60
# BRAND_229A_COUNTRY_0C7D 60 0 60
# BRAND_229A_COUNTRY_A67D 60 0 60
# BRAND_A465_COUNTRY_907E 57 0 57
# BRAND_229A_COUNTRY_9891 58 0 58
# BRAND_229A_COUNTRY_88A3 58 0 58
# BRAND_229A_COUNTRY_4442 58 0 58
# BRAND_229A_COUNTRY_C51E 57 2 55
# BRAND_A465_COUNTRY_89F9 57 0 57
# BRAND_229A_COUNTRY_3AD0 57 0 57
# BRAND_A465_COUNTRY_5180 57 0 57
# BRAND_229A_COUNTRY_6C16 56 0 56
# BRAND_229A_COUNTRY_2E65 56 1 55
# BRAND_F427_COUNTRY_4D48 55 2 53
# BRAND_229A_COUNTRY_53A5 54 1 53
# BRAND_229A_COUNTRY_1007 52 0 52
# BRAND_229A_COUNTRY_5FEB 52 0 52
# BRAND_229A_COUNTRY_8DBB 51 2 49
# BRAND_D759_COUNTRY_4242 3 0 3
# BRAND_229A_COUNTRY_0309 48 0 48
# BRAND_229A_COUNTRY_6B71 47 3 44
# BRAND_E7DC_COUNTRY_6F78 47 2 45
# BRAND_A465_COUNTRY_9488 33 2 31
# BRAND_229A_COUNTRY_3536 47 1 46
# BRAND_E2F0_COUNTRY_D8B0 3 0 3
# BRAND_4A99_COUNTRY_9488 14 1 13
# BRAND_5C8A_COUNTRY_D8B0 2 0 2
# BRAND_9EC1_COUNTRY_D8B0 3 0 3
# BRAND_4A99_COUNTRY_907E 3 0 3
# keep/ignore 29 5
# part 2 done
# ignores done.
# part 3 done
# data size (1540, 23) (17, 23)
# check set()
# lags done.
# after lags (1192, 50)
# check set()
# train data (1192, 46) (1192,)
# iterative fit starts
# BRAND_229A_COUNTRY_2E65
# 44 1
# BRAND_229A_COUNTRY_3536
# 35 1
# BRAND_229A_COUNTRY_53A5
# 42 1
# BRAND_229A_COUNTRY_6B71
# 35 3
# BRAND_229A_COUNTRY_8DBB
# 39 2
# BRAND_229A_COUNTRY_C51E
# 45 2
# BRAND_4A99_COUNTRY_9488
# 2 1
# BRAND_A465_COUNTRY_9488
# 21 2
# BRAND_E7DC_COUNTRY_6F78
# 35 2
# BRAND_F427_COUNTRY_4D48
# 43 2
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 166
# (372, 23)
# select
# train    353
# test      19
# Name: count, dtype: int64
# part 1 done
# BRAND_39B3_COUNTRY_FA79 38 2 36
# BRAND_CBF9_COUNTRY_B6AE 36 0 36
# BRAND_39B3_COUNTRY_3AD0 35 3 32
# BRAND_CBF9_COUNTRY_4D48 34 1 33
# BRAND_39B3_COUNTRY_1007 31 1 30
# BRAND_39B3_COUNTRY_0C7D 31 1 30
# BRAND_CBF9_COUNTRY_8DBB 28 1 27
# BRAND_CBF9_COUNTRY_4253 28 1 27
# BRAND_CBF9_COUNTRY_445D 27 1 26
# BRAND_CBF9_COUNTRY_B835 26 4 22
# BRAND_CBF9_COUNTRY_221C 20 3 17
# BRAND_39B3_COUNTRY_88A3 19 1 18
# keep/ignore 12 0
# part 2 done
# ignores done.
# part 3 done
# data size (353, 23) (19, 23)
# check set()
# lags done.
# after lags (209, 50)
# check set()
# train data (209, 46) (209,)
# iterative fit starts
# BRAND_39B3_COUNTRY_0C7D
# 19 1
# BRAND_39B3_COUNTRY_1007
# 19 1
# BRAND_39B3_COUNTRY_3AD0
# 23 3
# BRAND_39B3_COUNTRY_88A3
# 7 1
# BRAND_39B3_COUNTRY_FA79
# 26 2
# BRAND_CBF9_COUNTRY_221C
# 8 3
# BRAND_CBF9_COUNTRY_4253
# 16 1
# BRAND_CBF9_COUNTRY_445D
# 15 1
# BRAND_CBF9_COUNTRY_4D48
# 22 1
# BRAND_CBF9_COUNTRY_8DBB
# 16 1
# BRAND_CBF9_COUNTRY_B835
# 14 4
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 35
# (677, 23)
# select
# train    643
# test      34
# Name: count, dtype: int64
# part 1 done
# BRAND_2B96_COUNTRY_D8B0 46 2 44
# BRAND_2B96_COUNTRY_89F9 46 0 46
# BRAND_106A_COUNTRY_8DBB 45 2 43
# BRAND_2B96_COUNTRY_0309 44 1 43
# BRAND_2B96_COUNTRY_9891 39 2 37
# BRAND_2B96_COUNTRY_06E4 38 1 37
# BRAND_2B96_COUNTRY_5180 37 0 37
# BRAND_2B96_COUNTRY_1007 37 2 35
# BRAND_2B96_COUNTRY_A67D 35 3 32
# BRAND_106A_COUNTRY_B6AE 31 0 31
# BRAND_106A_COUNTRY_445D 31 3 28
# BRAND_2B96_COUNTRY_3AD0 30 1 29
# BRAND_2B96_COUNTRY_6F78 26 0 26
# BRAND_106A_COUNTRY_4253 24 1 23
# BRAND_2B96_COUNTRY_221C 24 1 23
# BRAND_106A_COUNTRY_4442 23 2 21
# BRAND_2B96_COUNTRY_907E 22 2 20
# BRAND_2B96_COUNTRY_0C7D 16 0 16
# BRAND_2B96_COUNTRY_EA71 16 3 13
# BRAND_106A_COUNTRY_C51E 15 3 12
# BRAND_106A_COUNTRY_4D48 8 0 8
# BRAND_2B96_COUNTRY_9488 8 2 6
# BRAND_106A_COUNTRY_53A5 2 3 -1
# keep/ignore 20 3
# part 2 done
# ignores done.
# part 3 done
# data size (625, 23) (29, 23)
# check set()
# lags done.
# after lags (385, 50)
# check set()
# train data (385, 46) (385,)
# iterative fit starts
# BRAND_106A_COUNTRY_4253
# 12 1
# BRAND_106A_COUNTRY_4442
# 11 2
# BRAND_106A_COUNTRY_445D
# 19 3
# BRAND_106A_COUNTRY_8DBB
# 33 2
# BRAND_106A_COUNTRY_C51E
# 3 3
# BRAND_2B96_COUNTRY_0309
# 32 1
# BRAND_2B96_COUNTRY_06E4
# 26 1
# BRAND_2B96_COUNTRY_1007
# 25 2
# BRAND_2B96_COUNTRY_221C
# 12 1
# BRAND_2B96_COUNTRY_3AD0
# 18 1
# BRAND_2B96_COUNTRY_907E
# 10 2
# BRAND_2B96_COUNTRY_9891
# 27 2
# BRAND_2B96_COUNTRY_A67D
# 23 3
# BRAND_2B96_COUNTRY_D8B0
# 34 2
# BRAND_2B96_COUNTRY_EA71
# 4 3
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 242
# (162, 23)
# select
# train    147
# test      15
# Name: count, dtype: int64
# part 1 done
# BRAND_19E3_COUNTRY_D8B0 31 1 30
# BRAND_19E3_COUNTRY_D5B9 26 4 22
# BRAND_19E3_COUNTRY_4442 24 1 23
# BRAND_19E3_COUNTRY_9488 23 0 23
# BRAND_19E3_COUNTRY_3AD0 21 4 17
# BRAND_19E3_COUNTRY_06E4 19 2 17
# BRAND_19E3_COUNTRY_B6AE 3 3 0
# keep/ignore 6 1
# part 2 done
# ignores done.
# part 3 done
# data size (144, 23) (12, 23)
# check set()
# lags done.
# after lags (72, 50)
# check set()
# train data (72, 46) (72,)
# iterative fit starts
# BRAND_19E3_COUNTRY_06E4
# 7 2
# BRAND_19E3_COUNTRY_3AD0
# 9 4
# BRAND_19E3_COUNTRY_4442
# 12 1
# BRAND_19E3_COUNTRY_D5B9
# 14 4
# BRAND_19E3_COUNTRY_D8B0
# 19 1
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 111
# (509, 23)
# select
# train    489
# test      20
# Name: count, dtype: int64
# part 1 done
# BRAND_B931_COUNTRY_D5B9 59 0 59
# BRAND_DBDD_COUNTRY_D8B0 12 0 12
# BRAND_B931_COUNTRY_9891 3 0 3
# BRAND_6646_COUNTRY_9891 40 1 39
# BRAND_6646_COUNTRY_D8B0 43 0 43
# BRAND_6646_COUNTRY_4242 47 2 45
# BRAND_6646_COUNTRY_0309 48 0 48
# BRAND_6646_COUNTRY_907E 42 3 39
# BRAND_B931_COUNTRY_9488 1 0 1
# BRAND_6646_COUNTRY_9488 34 2 32
# BRAND_6646_COUNTRY_445D 26 0 26
# BRAND_6646_COUNTRY_4D48 24 1 23
# BRAND_B931_COUNTRY_4242 1 0 1
# BRAND_6646_COUNTRY_06E4 24 1 23
# BRAND_6646_COUNTRY_4253 21 4 17
# BRAND_6646_COUNTRY_EA71 19 1 18
# BRAND_6646_COUNTRY_FA79 19 3 16
# BRAND_6646_COUNTRY_B6AE 11 1 10
# BRAND_046E_COUNTRY_9891 6 0 6
# BRAND_D6FC_COUNTRY_9488 1 0 1
# BRAND_6646_COUNTRY_0C7D 7 1 6
# BRAND_8072_COUNTRY_9891 1 0 1
# keep/ignore 13 9
# part 2 done
# ignores done.
# part 3 done
# data size (446, 23) (18, 23)
# check set()
# lags done.
# after lags (290, 50)
# check set()
# train data (290, 46) (290,)
# iterative fit starts
# BRAND_6646_COUNTRY_06E4
# 12 1
# BRAND_6646_COUNTRY_4242
# 35 2
# BRAND_6646_COUNTRY_4253
# 9 4
# BRAND_6646_COUNTRY_4D48
# 12 1
# BRAND_6646_COUNTRY_907E
# 30 3
# BRAND_6646_COUNTRY_9488
# 22 2
# BRAND_6646_COUNTRY_9891
# 28 1
# BRAND_6646_COUNTRY_EA71
# 7 1
# BRAND_6646_COUNTRY_FA79
# 7 3
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 135
# (346, 23)
# select
# train    345
# test       1
# Name: count, dtype: int64
# part 1 done
# BRAND_44D9_COUNTRY_AE54 60 0 60
# BRAND_44D9_COUNTRY_6B71 60 0 60
# BRAND_44D9_COUNTRY_B835 60 0 60
# BRAND_44D9_COUNTRY_E319 58 0 58
# BRAND_44D9_COUNTRY_0C7D 56 1 55
# BRAND_44D9_COUNTRY_221C 51 0 51
# keep/ignore 6 0
# part 2 done
# ignores done.
# part 3 done
# data size (345, 23) (1, 23)
# check set()
# lags done.
# after lags (273, 50)
# check set()
# train data (273, 46) (273,)
# iterative fit starts
# BRAND_44D9_COUNTRY_0C7D
# 44 1
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 198
# (1212, 23)
# select
# train    1199
# test       13
# Name: count, dtype: int64
# part 1 done
# BRAND_C020_COUNTRY_4442 60 0 60
# BRAND_C020_COUNTRY_06E4 60 0 60
# BRAND_CB17_COUNTRY_907E 58 0 58
# BRAND_C020_COUNTRY_3AD0 60 0 60
# BRAND_C020_COUNTRY_4242 50 0 50
# BRAND_C020_COUNTRY_D5B9 60 0 60
# BRAND_AC71_COUNTRY_53A5 60 0 60
# BRAND_CB17_COUNTRY_D8B0 46 0 46
# BRAND_C020_COUNTRY_6F78 58 1 57
# BRAND_C020_COUNTRY_C51E 57 2 55
# BRAND_C020_COUNTRY_445D 56 2 54
# BRAND_CB17_COUNTRY_0309 56 1 55
# BRAND_C020_COUNTRY_4D48 55 0 55
# BRAND_C020_COUNTRY_2E65 54 0 54
# BRAND_C020_COUNTRY_1007 42 0 42
# BRAND_CB17_COUNTRY_88A3 53 0 53
# BRAND_C020_COUNTRY_6B71 53 1 52
# BRAND_174C_COUNTRY_4242 7 0 7
# BRAND_C020_COUNTRY_FA79 51 3 48
# BRAND_C020_COUNTRY_3536 46 1 45
# BRAND_CB17_COUNTRY_5180 45 0 45
# BRAND_CB17_COUNTRY_8DBB 45 2 43
# BRAND_853C_COUNTRY_4242 3 0 3
# BRAND_20B9_COUNTRY_4253 38 0 38
# BRAND_2142_COUNTRY_1007 11 0 11
# BRAND_82A4_COUNTRY_D8B0 13 0 13
# BRAND_2142_COUNTRY_907E 2 0 2
# keep/ignore 23 4
# part 2 done
# ignores done.
# part 3 done
# data size (1176, 23) (13, 23)
# check set()
# lags done.
# after lags (900, 50)
# check set()
# train data (900, 46) (900,)
# iterative fit starts
# BRAND_C020_COUNTRY_3536
# 34 1
# BRAND_C020_COUNTRY_445D
# 44 2
# BRAND_C020_COUNTRY_6B71
# 41 1
# BRAND_C020_COUNTRY_6F78
# 46 1
# BRAND_C020_COUNTRY_C51E
# 45 2
# BRAND_C020_COUNTRY_FA79
# 39 3
# BRAND_CB17_COUNTRY_0309
# 44 1
# BRAND_CB17_COUNTRY_8DBB
# 33 2
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 23
# (402, 23)
# select
# train    375
# test      27
# Name: count, dtype: int64
# part 1 done
# BRAND_29F9_COUNTRY_0309 38 2 36
# BRAND_29F9_COUNTRY_D8B0 37 2 35
# BRAND_29F9_COUNTRY_445D 34 2 32
# BRAND_29F9_COUNTRY_53A5 31 1 30
# BRAND_29F9_COUNTRY_4242 30 0 30
# BRAND_29F9_COUNTRY_89F9 28 4 24
# BRAND_29F9_COUNTRY_9891 28 1 27
# BRAND_29F9_COUNTRY_6F78 25 1 24
# BRAND_29F9_COUNTRY_B6AE 24 3 21
# BRAND_29F9_COUNTRY_1007 24 0 24
# BRAND_29F9_COUNTRY_FA79 21 3 18
# BRAND_29F9_COUNTRY_4253 18 2 16
# BRAND_29F9_COUNTRY_B835 15 1 14
# BRAND_29F9_COUNTRY_D5B9 11 1 10
# BRAND_29F9_COUNTRY_3AD0 11 1 10
# BRAND_29F9_COUNTRY_5FEB 0 3 -3
# keep/ignore 13 3
# part 2 done
# ignores done.
# part 3 done
# data size (353, 23) (22, 23)
# check set()
# lags done.
# after lags (197, 50)
# check set()
# train data (197, 46) (197,)
# iterative fit starts
# BRAND_29F9_COUNTRY_0309
# 26 2
# BRAND_29F9_COUNTRY_4253
# 6 2
# BRAND_29F9_COUNTRY_445D
# 22 2
# BRAND_29F9_COUNTRY_53A5
# 19 1
# BRAND_29F9_COUNTRY_6F78
# 13 1
# BRAND_29F9_COUNTRY_89F9
# 16 4
# BRAND_29F9_COUNTRY_9891
# 16 1
# BRAND_29F9_COUNTRY_B6AE
# 12 3
# BRAND_29F9_COUNTRY_B835
# 3 1
# BRAND_29F9_COUNTRY_D8B0
# 25 2
# BRAND_29F9_COUNTRY_FA79
# 9 3
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 65
# (1394, 23)
# select
# train    1366
# test       28
# Name: count, dtype: int64
# part 1 done
# BRAND_CFD9_COUNTRY_B6AE 60 0 60
# BRAND_CFD9_COUNTRY_D8B0 60 0 60
# BRAND_CFD9_COUNTRY_3AD0 60 0 60
# ...
# BRAND_51B0_COUNTRY_C51E 58 0 58
# BRAND_51B0_COUNTRY_C89B 46 3 43
# BRAND_A531_COUNTRY_D8B0 2 0 2
# BRAND_51B0_COUNTRY_AE54 13 0 13
# keep/ignore 22 3
# part 2 done
# ignores done.
# part 3 done
# data size (1248, 23) (3, 23)
# check set()
# lags done.
# after lags (984, 50)
# check set()
# train data (984, 46) (984,)
# iterative fit starts
# BRAND_51B0_COUNTRY_C89B
# 34 3
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 202
# (337, 23)
# select
# train    335
# test       2
# Name: count, dtype: int64
# part 1 done
# BRAND_50D8_COUNTRY_FA79 60 0 60
# BRAND_50D8_COUNTRY_3AD0 60 0 60
# BRAND_50D8_COUNTRY_5180 60 0 60
# BRAND_4939_COUNTRY_445D 60 0 60
# BRAND_50D8_COUNTRY_6B71 48 1 47
# BRAND_355E_COUNTRY_4242 20 1 19
# BRAND_50D8_COUNTRY_4242 27 0 27
# keep/ignore 7 0
# part 2 done
# ignores done.
# part 3 done
# data size (335, 23) (2, 23)
# check set()
# lags done.
# after lags (251, 50)
# check set()
# train data (251, 46) (251,)
# iterative fit starts
# BRAND_355E_COUNTRY_4242
# 8 1
# BRAND_50D8_COUNTRY_6B71
# 36 1
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 238
# (643, 23)
# select
# train    641
# test       2
# Name: count, dtype: int64
# part 1 done
# BRAND_F886_COUNTRY_9891 60 0 60
# BRAND_F886_COUNTRY_907E 60 0 60
# BRAND_F886_COUNTRY_53A5 60 0 60
# BRAND_F886_COUNTRY_4242 58 0 58
# BRAND_F886_COUNTRY_D5B9 60 0 60
# BRAND_F886_COUNTRY_6C16 60 0 60
# BRAND_F886_COUNTRY_1007 60 0 60
# BRAND_F886_COUNTRY_89F9 60 0 60
# BRAND_F886_COUNTRY_2E65 60 0 60
# BRAND_F886_COUNTRY_D8B0 1 0 1
# BRAND_F886_COUNTRY_4D48 60 0 60
# BRAND_FA95_COUNTRY_4242 2 0 2
# BRAND_F886_COUNTRY_3AD0 40 2 38
# keep/ignore 11 2
# part 2 done
# ignores done.
# part 3 done
# data size (638, 23) (2, 23)
# check set()
# lags done.
# after lags (506, 50)
# check set()
# train data (506, 46) (506,)
# iterative fit starts
# BRAND_F886_COUNTRY_3AD0
# 28 2
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 152
# (15, 23)
# select
# train    14
# test      1
# Name: count, dtype: int64
# part 1 done
# BRAND_5E80_COUNTRY_445D 14 1 13
# keep/ignore 1 0
# part 2 done
# ignores done.
# part 3 done
# data size (14, 23) (1, 23)
# check set()
# lags done.
# after lags (2, 50)
# check set()
# train data (2, 46) (2,)
# iterative fit starts
# BRAND_5E80_COUNTRY_445D
# 2 1
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 210
# (11, 23)
# select
# train    10
# test      1
# Name: count, dtype: int64
# part 1 done
# BRAND_B7AE_COUNTRY_53A5 10 1 9
# keep/ignore 0 1
# part 2 done
# ignores done.
# part 3 done
# skip next
# ---------------------------------------
# drug_id 149
# (52, 23)
# select
# train    51
# test      1
# Name: count, dtype: int64
# part 1 done
# BRAND_C222_COUNTRY_2E65 51 1 50
# keep/ignore 1 0
# part 2 done
# ignores done.
# part 3 done
# data size (51, 23) (1, 23)
# check set()
# lags done.
# after lags (39, 50)
# check set()
# train data (39, 46) (39,)
# iterative fit starts
# BRAND_C222_COUNTRY_2E65
# 39 1
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 76
# (31, 23)
# select
# train    29
# test      2
# Name: count, dtype: int64
# part 1 done
# BRAND_7205_COUNTRY_AE54 29 2 27
# keep/ignore 1 0
# part 2 done
# ignores done.
# part 3 done
# data size (29, 23) (2, 23)
# check set()
# lags done.
# after lags (17, 50)
# check set()
# train data (17, 46) (17,)
# iterative fit starts
# BRAND_7205_COUNTRY_AE54
# 17 2
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 231
# (92, 23)
# select
# train    88
# test      4
# Name: count, dtype: int64
# part 1 done
# BRAND_17DE_COUNTRY_D8B0 38 3 35
# BRAND_17DE_COUNTRY_89F9 33 0 33
# BRAND_17DE_COUNTRY_907E 17 1 16
# keep/ignore 3 0
# part 2 done
# ignores done.
# part 3 done
# data size (88, 23) (4, 23)
# check set()
# lags done.
# after lags (52, 50)
# check set()
# train data (52, 46) (52,)
# iterative fit starts
# BRAND_17DE_COUNTRY_907E
# 5 1
# BRAND_17DE_COUNTRY_D8B0
# 26 3
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 2
# (443, 23)
# select
# train    440
# test       3
# Name: count, dtype: int64
# part 1 done
# BRAND_6E6E_COUNTRY_9488 60 0 60
# BRAND_6E6E_COUNTRY_907E 60 0 60
# BRAND_6E6E_COUNTRY_B6AE 60 0 60
# BRAND_6E6E_COUNTRY_4253 60 0 60
# BRAND_6E6E_COUNTRY_0C7D 60 0 60
# BRAND_6E6E_COUNTRY_221C 49 0 49
# BRAND_6E6E_COUNTRY_6C16 44 1 43
# BRAND_6E6E_COUNTRY_4D48 1 0 1
# BRAND_6E6E_COUNTRY_FA79 32 1 31
# BRAND_6E6E_COUNTRY_3AD0 14 1 13
# keep/ignore 9 1
# part 2 done
# ignores done.
# part 3 done
# data size (439, 23) (3, 23)
# check set()
# lags done.
# after lags (331, 50)
# check set()
# train data (331, 46) (331,)
# iterative fit starts
# BRAND_6E6E_COUNTRY_3AD0
# 2 1
# BRAND_6E6E_COUNTRY_6C16
# 32 1
# BRAND_6E6E_COUNTRY_FA79
# 20 1
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 16
# (86, 23)
# select
# train    82
# test      4
# Name: count, dtype: int64
# part 1 done
# BRAND_3B19_COUNTRY_907E 52 1 51
# BRAND_3B19_COUNTRY_3AD0 30 3 27
# keep/ignore 2 0
# part 2 done
# ignores done.
# part 3 done
# data size (82, 23) (4, 23)
# check set()
# lags done.
# after lags (58, 50)
# check set()
# train data (58, 46) (58,)
# iterative fit starts
# BRAND_3B19_COUNTRY_3AD0
# 18 3
# BRAND_3B19_COUNTRY_907E
# 40 1
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 33
# (834, 23)
# select
# train    832
# test       2
# Name: count, dtype: int64
# part 1 done
# BRAND_31DA_COUNTRY_4D48 60 0 60
# BRAND_31DA_COUNTRY_4442 60 0 60
# BRAND_5D0A_COUNTRY_3AD0 60 0 60
# BRAND_5D0A_COUNTRY_4242 60 0 60
# BRAND_5D0A_COUNTRY_5180 60 0 60
# BRAND_5D0A_COUNTRY_1007 60 0 60
# BRAND_5D0A_COUNTRY_6F78 60 0 60
# BRAND_5D0A_COUNTRY_6B71 60 0 60
# BRAND_31DA_COUNTRY_4253 60 0 60
# BRAND_5D0A_COUNTRY_907E 60 0 60
# BRAND_5D0A_COUNTRY_89F9 60 0 60
# BRAND_5D0A_COUNTRY_EA71 60 0 60
# BRAND_5D0A_COUNTRY_5FEB 59 0 59
# BRAND_1202_COUNTRY_E319 52 2 50
# BRAND_5D0A_COUNTRY_9488 1 0 1
# keep/ignore 14 1
# part 2 done
# ignores done.
# part 3 done
# data size (831, 23) (2, 23)
# check set()
# lags done.
# after lags (663, 50)
# check set()
# train data (663, 46) (663,)
# iterative fit starts
# BRAND_1202_COUNTRY_E319
# 40 2
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 47
# (107, 23)
# select
# train    106
# test       1
# Name: count, dtype: int64
# part 1 done
# BRAND_6D47_COUNTRY_89F9 54 0 54
# BRAND_6D47_COUNTRY_D8B0 52 1 51
# keep/ignore 2 0
# part 2 done
# ignores done.
# part 3 done
# data size (106, 23) (1, 23)
# check set()
# lags done.
# after lags (82, 50)
# check set()
# train data (82, 46) (82,)
# iterative fit starts
# BRAND_6D47_COUNTRY_D8B0
# 40 1
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 57
# (49, 23)
# select
# train    47
# test      2
# Name: count, dtype: int64
# part 1 done
# BRAND_6ABB_COUNTRY_53A5 25 1 24
# BRAND_6ABB_COUNTRY_D8B0 13 1 12
# BRAND_6ABB_COUNTRY_89F9 9 0 9
# keep/ignore 2 1
# part 2 done
# ignores done.
# part 3 done
# data size (38, 23) (2, 23)
# check set()
# lags done.
# after lags (14, 50)
# check set()
# train data (14, 46) (14,)
# iterative fit starts
# BRAND_6ABB_COUNTRY_53A5
# 13 1
# BRAND_6ABB_COUNTRY_D8B0
# 1 1
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 212
# (16, 23)
# select
# train    14
# test      2
# Name: count, dtype: int64
# part 1 done
# BRAND_A7C2_COUNTRY_84C8 14 2 12
# keep/ignore 1 0
# part 2 done
# ignores done.
# part 3 done
# data size (14, 23) (2, 23)
# check set()
# lags done.
# after lags (2, 50)
# check set()
# train data (2, 46) (2,)
# iterative fit starts
# BRAND_A7C2_COUNTRY_84C8
# 2 2
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 120
# (988, 23)
# select
# train    987
# test       1
# Name: count, dtype: int64
# part 1 done
# BRAND_354E_COUNTRY_88A3 60 0 60
# BRAND_760C_COUNTRY_1007 56 0 56
# BRAND_354E_COUNTRY_6C16 60 0 60
# BRAND_354E_COUNTRY_6F78 60 0 60
# BRAND_354E_COUNTRY_5180 60 0 60
# BRAND_354E_COUNTRY_4442 60 0 60
# BRAND_354E_COUNTRY_0309 60 0 60
# BRAND_354E_COUNTRY_53A5 60 0 60
# BRAND_354E_COUNTRY_89F9 60 0 60
# BRAND_354E_COUNTRY_4D48 60 0 60
# BRAND_354E_COUNTRY_3AD0 60 0 60
# BRAND_354E_COUNTRY_9891 60 0 60
# BRAND_354E_COUNTRY_907E 60 0 60
# BRAND_354E_COUNTRY_B6AE 60 0 60
# BRAND_DE13_COUNTRY_1007 4 0 4
# BRAND_354E_COUNTRY_EA71 59 0 59
# BRAND_354E_COUNTRY_B835 49 0 49
# BRAND_354E_COUNTRY_E319 39 1 38
# keep/ignore 17 1
# part 2 done
# ignores done.
# part 3 done
# data size (983, 23) (1, 23)
# check set()
# lags done.
# after lags (779, 50)
# check set()
# train data (779, 46) (779,)
# iterative fit starts
# BRAND_354E_COUNTRY_E319
# 27 1
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 140
# (1, 23)
# select
# test    1
# Name: count, dtype: int64
# part 1 done
# BRAND_ED43_COUNTRY_7D31 0 1 -1
# keep/ignore 0 1
# part 2 done
# ignores done.
# part 3 done
# skip next
# ---------------------------------------
# drug_id 245
# (28, 23)
# select
# train    26
# test      2
# Name: count, dtype: int64
# part 1 done
# BRAND_8A8E_COUNTRY_445D 26 2 24
# keep/ignore 1 0
# part 2 done
# ignores done.
# part 3 done
# data size (26, 23) (2, 23)
# check set()
# lags done.
# after lags (14, 50)
# check set()
# train data (14, 46) (14,)
# iterative fit starts
# BRAND_8A8E_COUNTRY_445D
# 14 2
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 184
# (34, 23)
# select
# train    33
# test      1
# Name: count, dtype: int64
# part 1 done
# BRAND_C8FD_COUNTRY_AE54 33 1 32
# keep/ignore 1 0
# part 2 done
# ignores done.
# part 3 done
# data size (33, 23) (1, 23)
# check set()
# lags done.
# after lags (21, 50)
# check set()
# train data (21, 46) (21,)
# iterative fit starts
# BRAND_C8FD_COUNTRY_AE54
# 21 1
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 70
# (421, 23)
# select
# train    420
# test       1
# Name: count, dtype: int64
# part 1 done
# BRAND_12B2_COUNTRY_88A3 60 0 60
# BRAND_12B2_COUNTRY_907E 60 0 60
# BRAND_12B2_COUNTRY_5180 60 0 60
# BRAND_12B2_COUNTRY_5FEB 60 0 60
# BRAND_12B2_COUNTRY_4442 60 0 60
# BRAND_12B2_COUNTRY_4253 60 0 60
# BRAND_12B2_COUNTRY_B6AE 60 0 60
# BRAND_12B2_COUNTRY_AE54 0 1 -1
# keep/ignore 7 1
# part 2 done
# ignores done.
# part 3 done
# data size (420, 23) (0, 23)
# check set()
# lags done.
# after lags (336, 50)
# check set()
# train data (336, 46) (336,)
# iterative fit starts
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 4
# (536, 23)
# select
# train    535
# test       1
# Name: count, dtype: int64
# part 1 done
# BRAND_E551_COUNTRY_8DBB 60 0 60
# BRAND_E551_COUNTRY_FA79 60 0 60
# BRAND_E551_COUNTRY_1007 60 0 60
# BRAND_E551_COUNTRY_9488 60 0 60
# BRAND_E551_COUNTRY_907E 60 0 60
# BRAND_E551_COUNTRY_221C 60 0 60
# BRAND_E551_COUNTRY_5FEB 60 0 60
# BRAND_E551_COUNTRY_4442 60 0 60
# BRAND_E551_COUNTRY_4253 55 1 54
# keep/ignore 9 0
# part 2 done
# ignores done.
# part 3 done
# data size (535, 23) (1, 23)
# check set()
# lags done.
# after lags (427, 50)
# check set()
# train data (427, 46) (427,)
# iterative fit starts
# BRAND_E551_COUNTRY_4253
# 43 1
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 154
# (600, 23)
# select
# train    598
# test       2
# Name: count, dtype: int64
# part 1 done
# BRAND_AD1B_COUNTRY_9891 45 0 45
# BRAND_AD1B_COUNTRY_D8B0 60 0 60
# BRAND_AD1B_COUNTRY_89F9 60 0 60
# BRAND_AD1B_COUNTRY_D5B9 60 0 60
# BRAND_AD1B_COUNTRY_53A5 60 0 60
# BRAND_AD1B_COUNTRY_5180 60 0 60
# BRAND_AD1B_COUNTRY_907E 60 0 60
# BRAND_AD1B_COUNTRY_88A3 53 0 53
# BRAND_AD1B_COUNTRY_FA79 49 1 48
# BRAND_AD1B_COUNTRY_6F78 46 1 45
# BRAND_BE12_COUNTRY_9891 15 0 15
# BRAND_AD1B_COUNTRY_0C7D 30 0 30
# keep/ignore 12 0
# part 2 done
# ignores done.
# part 3 done
# data size (598, 23) (2, 23)
# check set()
# lags done.
# after lags (454, 50)
# check set()
# train data (454, 46) (454,)
# iterative fit starts
# BRAND_AD1B_COUNTRY_6F78
# 34 1
# BRAND_AD1B_COUNTRY_FA79
# 37 1
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 188
# (47, 23)
# select
# train    45
# test      2
# Name: count, dtype: int64
# part 1 done
# BRAND_3412_COUNTRY_4442 45 2 43
# keep/ignore 1 0
# part 2 done
# ignores done.
# part 3 done
# data size (45, 23) (2, 23)
# check set()
# lags done.
# after lags (33, 50)
# check set()
# train data (33, 46) (33,)
# iterative fit starts
# BRAND_3412_COUNTRY_4442
# 33 2
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 138
# (177, 23)
# select
# train    176
# test       1
# Name: count, dtype: int64
# part 1 done
# BRAND_0514_COUNTRY_3AD0 56 0 56
# BRAND_0514_COUNTRY_445D 51 0 51
# BRAND_E8CC_COUNTRY_53A5 43 1 42
# BRAND_0514_COUNTRY_4D48 26 0 26
# keep/ignore 4 0
# part 2 done
# ignores done.
# part 3 done
# data size (176, 23) (1, 23)
# check set()
# lags done.
# after lags (128, 50)
# check set()
# train data (128, 46) (128,)
# iterative fit starts
# BRAND_E8CC_COUNTRY_53A5
# 31 1
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 124
# (233, 23)
# select
# train    232
# test       1
# Name: count, dtype: int64
# part 1 done
# BRAND_35BE_COUNTRY_5FEB 60 0 60
# BRAND_35BE_COUNTRY_B6AE 60 0 60
# BRAND_35BE_COUNTRY_221C 60 0 60
# BRAND_35BE_COUNTRY_E319 52 1 51
# keep/ignore 4 0
# part 2 done
# ignores done.
# part 3 done
# data size (232, 23) (1, 23)
# check set()
# lags done.
# after lags (184, 50)
# check set()
# train data (184, 46) (184,)
# iterative fit starts
# BRAND_35BE_COUNTRY_E319
# 40 1
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 82
# (282, 23)
# select
# train    281
# test       1
# Name: count, dtype: int64
# part 1 done
# BRAND_E50F_COUNTRY_8B47 60 0 60
# BRAND_E50F_COUNTRY_FA79 60 0 60
# BRAND_E50F_COUNTRY_3F0E 60 0 60
# BRAND_E50F_COUNTRY_C51E 60 0 60
# BRAND_E50F_COUNTRY_4D48 41 1 40
# keep/ignore 5 0
# part 2 done
# ignores done.
# part 3 done
# data size (281, 23) (1, 23)
# check set()
# lags done.
# after lags (221, 50)
# check set()
# train data (221, 46) (221,)
# iterative fit starts
# BRAND_E50F_COUNTRY_4D48
# 29 1
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 178
# (155, 23)
# select
# train    154
# test       1
# Name: count, dtype: int64
# part 1 done
# BRAND_9423_COUNTRY_EA71 60 0 60
# BRAND_9423_COUNTRY_9488 60 0 60
# BRAND_9423_COUNTRY_5FEB 34 1 33
# keep/ignore 3 0
# part 2 done
# ignores done.
# part 3 done
# data size (154, 23) (1, 23)
# check set()
# lags done.
# after lags (118, 50)
# check set()
# train data (118, 46) (118,)
# iterative fit starts
# BRAND_9423_COUNTRY_5FEB
# 22 1
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 12
# (325, 23)
# select
# train    324
# test       1
# Name: count, dtype: int64
# part 1 done
# BRAND_7565_COUNTRY_8B47 60 0 60
# BRAND_7565_COUNTRY_3536 60 0 60
# BRAND_7565_COUNTRY_8DBB 60 0 60
# BRAND_7565_COUNTRY_89F9 60 0 60
# BRAND_138F_COUNTRY_7D31 56 1 55
# BRAND_7565_COUNTRY_1033 28 0 28
# keep/ignore 6 0
# part 2 done
# ignores done.
# part 3 done
# data size (324, 23) (1, 23)
# check set()
# lags done.
# after lags (252, 50)
# check set()
# train data (252, 46) (252,)
# iterative fit starts
# BRAND_138F_COUNTRY_7D31
# 44 1
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 233
# (229, 23)
# select
# train    228
# test       1
# Name: count, dtype: int64
# part 1 done
# BRAND_9BE6_COUNTRY_C51E 60 0 60
# BRAND_9BE6_COUNTRY_E319 60 0 60
# BRAND_9BE6_COUNTRY_3536 40 0 40
# BRAND_9BE6_COUNTRY_B6AE 46 0 46
# BRAND_ADDE_COUNTRY_3536 20 0 20
# BRAND_3C98_COUNTRY_B6AE 2 1 1
# keep/ignore 5 1
# part 2 done
# ignores done.
# part 3 done
# data size (226, 23) (0, 23)
# check set()
# lags done.
# after lags (166, 50)
# check set()
# train data (166, 46) (166,)
# iterative fit starts
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 237
# (32, 23)
# select
# train    31
# test      1
# Name: count, dtype: int64
# part 1 done
# BRAND_1989_COUNTRY_1007 31 1 30
# keep/ignore 1 0
# part 2 done
# ignores done.
# part 3 done
# data size (31, 23) (1, 23)
# check set()
# lags done.
# after lags (19, 50)
# check set()
# train data (19, 46) (19,)
# iterative fit starts
# BRAND_1989_COUNTRY_1007
# 19 1
# fit done.
# drug done -- > next
# ---------------------------------------
# drug_id 222
# (833, 23)
# select
# train    832
# test       1
# Name: count, dtype: int64
# part 1 done
# BRAND_626D_COUNTRY_8B47 60 0 60
# BRAND_626D_COUNTRY_5180 60 0 60
# BRAND_626D_COUNTRY_EF33 60 0 60
# BRAND_626D_COUNTRY_6B71 60 0 60
# BRAND_626D_COUNTRY_7D31 60 0 60
# BRAND_626D_COUNTRY_458E 60 0 60
# BRAND_626D_COUNTRY_6C16 60 0 60
# BRAND_626D_COUNTRY_77DA 60 0 60
# BRAND_626D_COUNTRY_2E65 60 0 60
# BRAND_626D_COUNTRY_B835 60 0 60
# BRAND_626D_COUNTRY_1033 60 0 60
# BRAND_626D_COUNTRY_4D48 60 0 60
# BRAND_626D_COUNTRY_4253 57 1 56
# BRAND_626D_COUNTRY_221C 55 0 55
# keep/ignore 14 0
# part 2 done
# ignores done.
# part 3 done
# data size (832, 23) (1, 23)
# check set()
# lags done.
# after lags (664, 50)
# check set()
# train data (664, 46) (664,)
# iterative fit starts
# BRAND_626D_COUNTRY_4253
# 45 1
# fit done.
# drug done -- > next
# ---------------------------------------
#  -- finished --

# %%
subs.head()
# Out:
#               date               cluster_nl    target
# 102631  2022-10-01  BRAND_62C7_COUNTRY_AE54  1.176204
# 104325  2022-11-01  BRAND_9FCC_COUNTRY_C89B  0.700967
# 104586  2022-06-01  BRAND_62C7_COUNTRY_AE54  1.015626
# 103324  2022-12-01  BRAND_62C7_COUNTRY_0C7D  0.784228
# 103035  2022-06-01  BRAND_62C7_COUNTRY_1007  1.199743

# %%
subs.isnull().sum()
# Out:
# date          0
# cluster_nl    0
# target        0
# dtype: int64

# %%
subs = subs.rename(columns={"target":"prediction"})
subs.head()
# Out:
#               date               cluster_nl  prediction
# 102631  2022-10-01  BRAND_62C7_COUNTRY_AE54    1.176204
# 104325  2022-11-01  BRAND_9FCC_COUNTRY_C89B    0.700967
# 104586  2022-06-01  BRAND_62C7_COUNTRY_AE54    1.015626
# 103324  2022-12-01  BRAND_62C7_COUNTRY_0C7D    0.784228
# 103035  2022-06-01  BRAND_62C7_COUNTRY_1007    1.199743

# %%
subs['prediction'] = np.expm1(subs['prediction'])
subs.head()
# Out:
#               date               cluster_nl  prediction
# 102631  2022-10-01  BRAND_62C7_COUNTRY_AE54    2.242045
# 104325  2022-11-01  BRAND_9FCC_COUNTRY_C89B    1.015701
# 104586  2022-06-01  BRAND_62C7_COUNTRY_AE54    1.761092
# 103324  2022-12-01  BRAND_62C7_COUNTRY_0C7D    1.190715
# 103035  2022-06-01  BRAND_62C7_COUNTRY_1007    2.319263

# %%
subs.to_csv(f"../abhi_data/submission_dummy_abhi2022_{dataset_no}_final.csv", sep=",", index=False)

# %% [markdown]
# # evaluation

# %%
subs = pd.read_csv(f"../abhi_data/submission_dummy_abhi2022_{dataset_no}_final.csv")
subs = subs.sort_values(["cluster_nl","date"])
subs.head()
# Out:
#            date               cluster_nl  prediction
# 150  2022-06-01  BRAND_0056_COUNTRY_06E4    1.108262
# 151  2022-01-01  BRAND_0056_COUNTRY_0C7D    1.171584
# 152  2022-04-01  BRAND_0056_COUNTRY_0C7D    1.179824
# 153  2022-10-01  BRAND_0056_COUNTRY_0C7D    1.171924
# 154  2022-11-01  BRAND_0056_COUNTRY_0C7D    1.166767

# %%
subs["target"] = targets1["target"].values
subs.head()
# Out:
#            date               cluster_nl  prediction    target
# 150  2022-06-01  BRAND_0056_COUNTRY_06E4    1.108262  1.112130
# 151  2022-01-01  BRAND_0056_COUNTRY_0C7D    1.171584  1.217491
# 152  2022-04-01  BRAND_0056_COUNTRY_0C7D    1.179824  1.209845
# 153  2022-10-01  BRAND_0056_COUNTRY_0C7D    1.171924  1.271516
# 154  2022-11-01  BRAND_0056_COUNTRY_0C7D    1.166767  1.311337

# %%
zl = list( set ( test.cluster_nl.unique() ) - set( train.cluster_nl.unique() ) )
zl[:10]
# Out:
# ['BRAND_D72F_COUNTRY_1033',
#  'BRAND_7E52_COUNTRY_A67D',
#  'BRAND_8F35_COUNTRY_6C16',
#  'BRAND_A12A_COUNTRY_C51E',
#  'BRAND_740F_COUNTRY_0309',
#  'BRAND_E57A_COUNTRY_88A3',
#  'BRAND_C352_COUNTRY_88A3',
#  'BRAND_C352_COUNTRY_445D',
#  'BRAND_60F2_COUNTRY_C89B',
#  'BRAND_143F_COUNTRY_6F78']

# %%
subs["zero_actuals"] = ~subs.cluster_nl.isin(zl)
subs.head()
# Out:
#            date               cluster_nl  prediction    target  zero_actuals
# 150  2022-06-01  BRAND_0056_COUNTRY_06E4    1.108262  1.112130          True
# 151  2022-01-01  BRAND_0056_COUNTRY_0C7D    1.171584  1.217491          True
# 152  2022-04-01  BRAND_0056_COUNTRY_0C7D    1.179824  1.209845          True
# 153  2022-10-01  BRAND_0056_COUNTRY_0C7D    1.171924  1.271516          True
# 154  2022-11-01  BRAND_0056_COUNTRY_0C7D    1.166767  1.311337          True

# %%
def _CYME(df: pd.DataFrame) -> float:
    """ Compute the CYME metric, that is 1/2(median(yearly error) + median(monthly error))"""
    
    yearly_agg = df.groupby("cluster_nl")[["target", "prediction"]].sum().reset_index()
    yearly_error = abs((yearly_agg["target"] - yearly_agg["prediction"])/yearly_agg["target"]).median()

    monthly_error = abs((df["target"] - df["prediction"])/df["target"]).median()

    print(f"yearly_error : {yearly_error}, monthly_error: {monthly_error}")

    return 1/2*(yearly_error + monthly_error)


def _metric(df: pd.DataFrame) -> float:
    """Compute metric of submission.

    :param df: Dataframe with target and 'prediction', and identifiers.
    :return: Performance metric
    """
    df = df.copy()
    df["date"] = pd.to_datetime(df["date"])

    # Split 0 actuals - rest
    zeros = df[df["zero_actuals"] == 1]
    recent = df[df["zero_actuals"] == 0]
    
    print("zeros")
    print(zeros)
    print("recent")
    print(recent)
    
    # weight for each group
    zeros_weight = len(zeros)/len(df)
    recent_weight = 1 - zeros_weight
    
    print(f"zeros_weight:  {zeros_weight}, recent_weight: {recent_weight}")
    
    # Compute CYME for each group
    part1 = recent_weight*_CYME(recent) # recent ha
    
    part2 = zeros_weight*min(1,_CYME(zeros)) # gheyre recent ha
    
    print(f"part1: {part1}, part2: {part2}")
    
    if not np.isnan( part1 ) and not np.isnan( part1 ):
        out = round(part1 + part2, 8)
    else:
        out = round(part2, 8)
    return out


def compute_metric(submission: pd.DataFrame) -> Tuple[float, float]:
    """Compute metric.

    :param submission: Prediction. Requires columns: ['cluster_nl', 'date', 'target', 'prediction']
    :return: Performance metric.
    """

    submission["date"] = pd.to_datetime(submission["date"])
    submission = submission[['cluster_nl', 'date', 'target', 'prediction', 'zero_actuals']]
    
    return _metric(submission)

# Optionally check performance
print("Performance:", compute_metric(subs))
# Out:
# zeros
#                    cluster_nl       date     target  prediction  zero_actuals
# 150   BRAND_0056_COUNTRY_06E4 2022-06-01   1.112130    1.108262          True
# 151   BRAND_0056_COUNTRY_0C7D 2022-01-01   1.217491    1.171584          True
# 152   BRAND_0056_COUNTRY_0C7D 2022-04-01   1.209845    1.179824          True
# 153   BRAND_0056_COUNTRY_0C7D 2022-10-01   1.271516    1.171924          True
# 154   BRAND_0056_COUNTRY_0C7D 2022-11-01   1.311337    1.166767          True
# 155   BRAND_0056_COUNTRY_1007 2022-11-01   3.328773    2.880366          True
# 156   BRAND_0056_COUNTRY_1007 2022-12-01   3.160442    2.892911          True
# 157   BRAND_0056_COUNTRY_221C 2022-01-01   1.101831    1.117524          True
# 158   BRAND_0056_COUNTRY_2E65 2022-08-01   1.017308    1.030306          True
# 159   BRAND_0056_COUNTRY_2E65 2022-09-01   1.022017    1.019640          True
# 160   BRAND_0056_COUNTRY_3F0E 2022-01-01   1.221783    1.274343          True
# 161   BRAND_0056_COUNTRY_4442 2022-05-01   2.274637    2.110391          True
# 162   BRAND_0056_COUNTRY_4442 2022-08-01   2.343218    2.430590          True
# 163   BRAND_0056_COUNTRY_4D48 2022-12-01   1.589450    1.512973          True
# 164   BRAND_0056_COUNTRY_6B71 2022-12-01   1.494379    1.404275          True
# 165   BRAND_0056_COUNTRY_6C16 2022-01-01   1.359032    1.475928          True
# 166   BRAND_0056_COUNTRY_6C16 2022-03-01   1.450104    1.587100          True
# 167   BRAND_0056_COUNTRY_6C16 2022-03-01   1.450104    1.601217          True
# 168   BRAND_0056_COUNTRY_6F78 2022-07-01   1.059544    1.077022          True
# 169   BRAND_0056_COUNTRY_77DA 2022-10-01   1.433292    1.310369          True
# 170   BRAND_0056_COUNTRY_84C8 2022-05-01   1.013084    1.010029          True
# 171   BRAND_0056_COUNTRY_84C8 2022-10-01   1.016523    1.015762          True
# 172   BRAND_0056_COUNTRY_88A3 2022-10-01   1.214674    1.221025          True
# 173   BRAND_0056_COUNTRY_89F9 2022-04-01   2.806044    2.310384          True
# 174   BRAND_0056_COUNTRY_89F9 2022-04-01   2.806044    2.704893          True
# 175   BRAND_0056_COUNTRY_89F9 2022-05-01   2.652153    2.434693          True
# 176   BRAND_0056_COUNTRY_8B47 2022-10-01   1.317880    1.206915          True
# 177   BRAND_0056_COUNTRY_8B47 2022-10-01   1.317880    1.218716          True
# 178   BRAND_0056_COUNTRY_8DBB 2022-01-01   1.214172    1.325572          True
# 179   BRAND_0056_COUNTRY_8DBB 2022-05-01   1.458646    1.287947          True
# 180   BRAND_0056_COUNTRY_8DBB 2022-07-01   1.647567    1.367408          True
# 181   BRAND_0056_COUNTRY_8DBB 2022-07-01   1.647567    1.374199          True
# 182   BRAND_0056_COUNTRY_907E 2022-01-01   3.069090    3.010434          True
# 183   BRAND_0056_COUNTRY_9488 2022-07-01   1.184481    1.208889          True
# 184   BRAND_0056_COUNTRY_9488 2022-08-01   1.250370    1.207221          True
# 185   BRAND_0056_COUNTRY_9488 2022-09-01   1.325089    1.239402          True
# 186   BRAND_0056_COUNTRY_9891 2022-01-01   1.415252    1.422797          True
# 187   BRAND_0056_COUNTRY_9891 2022-04-01   1.392733    1.380040          True
# 188   BRAND_0056_COUNTRY_A67D 2022-05-01   1.663654    1.547471          True
# 189   BRAND_0056_COUNTRY_A67D 2022-06-01   1.704556    1.551887          True
# 190   BRAND_0056_COUNTRY_B6AE 2022-02-01   1.152462    1.144866          True
# 191   BRAND_0056_COUNTRY_C51E 2022-04-01   1.165118    1.148979          True
# 192   BRAND_0056_COUNTRY_C51E 2022-06-01   1.179925    1.154006          True
# 193   BRAND_0056_COUNTRY_C51E 2022-08-01   1.158150    1.164448          True
# 194   BRAND_0056_COUNTRY_C89B 2022-02-01   1.030104    1.031456          True
# 195   BRAND_0056_COUNTRY_C89B 2022-03-01   1.043972    1.039008          True
# 196   BRAND_0056_COUNTRY_C89B 2022-09-01   1.036744    1.037669          True
# 197   BRAND_0056_COUNTRY_E319 2022-10-01   1.727226    1.307357          True
# 198   BRAND_0056_COUNTRY_E319 2022-12-01   1.258933    1.372902          True
# 199   BRAND_0056_COUNTRY_EA71 2022-11-01   1.400954    1.366966          True
# 200   BRAND_0056_COUNTRY_EF33 2022-01-01   1.228445    1.199538          True
# 201   BRAND_0056_COUNTRY_EF33 2022-08-01   1.325006    1.239746          True
# 202   BRAND_0056_COUNTRY_FA79 2022-05-01   1.073701    1.132935          True
# 203   BRAND_0056_COUNTRY_FA79 2022-07-01   1.090183    1.048735          True
# 204   BRAND_0056_COUNTRY_FA79 2022-10-01   1.102370    1.061305          True
# 1801  BRAND_00C0_COUNTRY_C51E 2022-04-01   1.237929    1.270881          True
# 260   BRAND_014B_COUNTRY_1007 2022-02-01   1.459758    1.468526          True
# 261   BRAND_014B_COUNTRY_1033 2022-06-01   1.030945    1.035828          True
# 262   BRAND_014B_COUNTRY_3536 2022-03-01   1.039204    1.039497          True
# 263   BRAND_014B_COUNTRY_3536 2022-04-01   1.033323    1.022485          True
# 264   BRAND_014B_COUNTRY_3536 2022-09-01   1.029616    1.008844          True
# 265   BRAND_014B_COUNTRY_3AD0 2022-03-01   1.310972    1.292115          True
# 255   BRAND_014B_COUNTRY_5180 2022-07-01   1.161567    1.041351          True
# 266   BRAND_014B_COUNTRY_6B71 2022-04-01   1.011065    1.025353          True
# 267   BRAND_014B_COUNTRY_89F9 2022-02-01   1.217482    1.178187          True
# 268   BRAND_014B_COUNTRY_89F9 2022-11-01   1.104562    1.207016          True
# 257   BRAND_014B_COUNTRY_8B47 2022-03-01   1.023693    1.006937          True
# 258   BRAND_014B_COUNTRY_8B47 2022-11-01   1.031055    1.008570          True
# 269   BRAND_014B_COUNTRY_907E 2022-09-01   1.627779    1.472054          True
# 1301  BRAND_0795_COUNTRY_FA79 2022-09-01   1.007878    1.007090          True
# 1302  BRAND_0795_COUNTRY_FA79 2022-10-01   1.005134    1.005213          True
# 1235  BRAND_07D5_COUNTRY_221C 2022-01-01   1.957833    1.717299          True
# 1236  BRAND_07D5_COUNTRY_221C 2022-03-01   1.611004    1.602549          True
# 1237  BRAND_07D5_COUNTRY_221C 2022-04-01   1.862935    1.604227          True
# 1238  BRAND_07D5_COUNTRY_221C 2022-07-01   1.644091    1.726895          True
# 1134  BRAND_09DD_COUNTRY_445D 2022-01-01   1.058677    1.066862          True
# 1135  BRAND_09DD_COUNTRY_445D 2022-01-01   1.058677    1.068567          True
# 1136  BRAND_09DD_COUNTRY_445D 2022-04-01   1.066501    1.078140          True
# 962   BRAND_09DF_COUNTRY_0309 2022-09-01   1.408674    1.407989          True
# 963   BRAND_09DF_COUNTRY_0309 2022-09-01   1.408674    1.466782          True
# 964   BRAND_09DF_COUNTRY_0309 2022-11-01   1.391364    1.569237          True
# 965   BRAND_09DF_COUNTRY_1007 2022-06-01   1.817320    1.789116          True
# 966   BRAND_09DF_COUNTRY_6F78 2022-09-01   1.035448    1.036864          True
# 967   BRAND_09DF_COUNTRY_907E 2022-05-01   1.512512    1.519267          True
# 968   BRAND_09DF_COUNTRY_907E 2022-06-01   1.554337    1.501079          True
# 969   BRAND_09DF_COUNTRY_EA71 2022-06-01   1.101277    1.057644          True
# 970   BRAND_09DF_COUNTRY_EA71 2022-08-01   1.097531    1.059863          True
# 971   BRAND_09DF_COUNTRY_FA79 2022-03-01   1.016831    1.028088          True
# 972   BRAND_09DF_COUNTRY_FA79 2022-04-01   1.021714    1.036385          True
# 973   BRAND_09DF_COUNTRY_FA79 2022-09-01   1.045484    1.039860          True
# 1838  BRAND_0A53_COUNTRY_221C 2022-07-01   1.021185    1.011882          True
# 77    BRAND_0E5A_COUNTRY_0309 2022-04-01   2.593404    2.857965          True
# 78    BRAND_0E5A_COUNTRY_0309 2022-09-01   2.777563    2.679676          True
# 79    BRAND_0E5A_COUNTRY_0309 2022-10-01   2.828943    3.216282          True
# 80    BRAND_0E5A_COUNTRY_1007 2022-06-01   2.808028    2.955725          True
# 72    BRAND_0E5A_COUNTRY_4253 2022-01-01   1.257281    1.182420          True
# 75    BRAND_0E5A_COUNTRY_4253 2022-03-01   1.349455    1.177319          True
# 74    BRAND_0E5A_COUNTRY_4253 2022-11-01   1.747681    1.190035          True
# 81    BRAND_0E5A_COUNTRY_907E 2022-07-01   2.915381    2.586256          True
# 82    BRAND_0E5A_COUNTRY_9891 2022-05-01   1.197425    1.215157          True
# 83    BRAND_0E5A_COUNTRY_C8F4 2022-04-01   1.035077    1.114565          True
# 84    BRAND_0E5A_COUNTRY_D8B0 2022-01-01   1.889132    1.847290          True
# 85    BRAND_0E5A_COUNTRY_D8B0 2022-08-01   2.266833    1.864929          True
# 73    BRAND_0E5A_COUNTRY_FA79 2022-01-01   1.053678    1.037563          True
# 76    BRAND_0E5A_COUNTRY_FA79 2022-05-01   1.054728    1.039843          True
# 71    BRAND_0E5A_COUNTRY_FA79 2022-08-01   1.068189    1.042126          True
# 1303  BRAND_0F47_COUNTRY_53A5 2022-02-01   2.870695    2.946739          True
# 715   BRAND_106A_COUNTRY_4253 2022-03-01   1.532022    1.404558          True
# 716   BRAND_106A_COUNTRY_4442 2022-08-01   1.910039    1.562888          True
# 717   BRAND_106A_COUNTRY_4442 2022-09-01   1.991304    1.559054          True
# 718   BRAND_106A_COUNTRY_445D 2022-02-01   1.483388    1.529742          True
# 719   BRAND_106A_COUNTRY_445D 2022-03-01   1.699667    1.574368          True
# 720   BRAND_106A_COUNTRY_445D 2022-10-01   1.709991    1.775140          True
# 714   BRAND_106A_COUNTRY_53A5 2022-08-01   2.282383    1.108488          True
# 711   BRAND_106A_COUNTRY_53A5 2022-10-01   2.296840    1.076321          True
# 713   BRAND_106A_COUNTRY_53A5 2022-11-01   2.355909    1.068943          True
# 721   BRAND_106A_COUNTRY_8DBB 2022-05-01   1.131719    1.118537          True
# 722   BRAND_106A_COUNTRY_8DBB 2022-08-01   1.078544    1.134413          True
# 723   BRAND_106A_COUNTRY_C51E 2022-05-01   1.160160    1.095696          True
# 724   BRAND_106A_COUNTRY_C51E 2022-07-01   1.164526    1.090176          True
# 725   BRAND_106A_COUNTRY_C51E 2022-08-01   1.161643    1.098528          True
# 1974  BRAND_1202_COUNTRY_E319 2022-04-01   1.006390    1.006935          True
# 1975  BRAND_1202_COUNTRY_E319 2022-05-01   1.005836    1.008170          True
# 1996  BRAND_138F_COUNTRY_7D31 2022-04-01   1.089912    1.051970          True
# 1215  BRAND_13B2_COUNTRY_1007 2022-03-01   1.316933    1.073058          True
# 1217  BRAND_13B2_COUNTRY_1007 2022-06-01   1.379382    1.073058          True
# 1214  BRAND_13B2_COUNTRY_1007 2022-07-01   1.409468    1.073058          True
# 1218  BRAND_13B2_COUNTRY_1007 2022-07-01   1.409468    1.073058          True
# 1221  BRAND_13B2_COUNTRY_2E65 2022-03-01   1.004791    1.010319          True
# 1222  BRAND_13B2_COUNTRY_3536 2022-12-01   1.012587    1.007064          True
# 1223  BRAND_13B2_COUNTRY_3AD0 2022-12-01   1.015493    1.081841          True
# 1224  BRAND_13B2_COUNTRY_4242 2022-08-01   1.000406    1.003294          True
# 1225  BRAND_13B2_COUNTRY_6B71 2022-06-01   1.077690    1.272760          True
# 1226  BRAND_13B2_COUNTRY_6F78 2022-08-01   1.006943    0.939008          True
# 1227  BRAND_13B2_COUNTRY_84C8 2022-05-01   1.003956    1.018292          True
# 1228  BRAND_13B2_COUNTRY_907E 2022-12-01   1.050149    1.286065          True
# 1229  BRAND_13B2_COUNTRY_B6AE 2022-03-01   1.035660    1.092965          True
# 1230  BRAND_13B2_COUNTRY_B6AE 2022-03-01   1.035660    1.485893          True
# 1216  BRAND_13B2_COUNTRY_D8B0 2022-01-01   1.037502    1.003363          True
# 1220  BRAND_13B2_COUNTRY_D8B0 2022-03-01   1.048749    1.003363          True
# 1029  BRAND_2B62_COUNTRY_4253 2022-04-01   1.443347    1.253120          True
# 1030  BRAND_2B62_COUNTRY_6F78 2022-06-01   1.294663    1.347601          True
# 1031  BRAND_2B62_COUNTRY_89F9 2022-04-01   3.472404    3.049420          True
# 1032  BRAND_2B62_COUNTRY_89F9 2022-10-01   4.069100    3.097817          True
# 1033  BRAND_2B62_COUNTRY_9891 2022-12-01   1.096722    1.094593          True
# 1034  BRAND_2B62_COUNTRY_A67D 2022-06-01   1.450915    1.494001          True
# 1035  BRAND_2B62_COUNTRY_B6AE 2022-07-01   1.126660    1.070075          True
# 1036  BRAND_2B62_COUNTRY_C51E 2022-03-01   1.131169    1.130312          True
# 1037  BRAND_2B62_COUNTRY_C51E 2022-04-01   1.139467    1.061107          True
# 1038  BRAND_2B62_COUNTRY_D5B9 2022-01-01   1.009660    1.040197          True
# 1039  BRAND_2B62_COUNTRY_D5B9 2022-01-01   1.009660    1.056138          True
# 1040  BRAND_2B62_COUNTRY_D5B9 2022-03-01   1.016086    1.035732          True
# 1041  BRAND_2B62_COUNTRY_D8B0 2022-03-01   7.368693    6.060209          True
# 1042  BRAND_2B62_COUNTRY_D8B0 2022-08-01   8.219458    6.238031          True
# 1043  BRAND_2B62_COUNTRY_D8B0 2022-11-01   6.864970    6.154651          True
# 1044  BRAND_2B62_COUNTRY_FA79 2022-01-01   1.115599    1.149459          True
# 1045  BRAND_2B62_COUNTRY_FA79 2022-09-01   1.126678    1.123868          True
# 1046  BRAND_2B62_COUNTRY_FA79 2022-09-01   1.126678    1.092083          True
# 726   BRAND_2B96_COUNTRY_0309 2022-12-01   3.490348    3.213554          True
# 727   BRAND_2B96_COUNTRY_06E4 2022-11-01   1.144564    1.253565          True
# 728   BRAND_2B96_COUNTRY_1007 2022-01-01   2.740865    2.574019          True
# 729   BRAND_2B96_COUNTRY_1007 2022-03-01   3.145563    2.553800          True
# 730   BRAND_2B96_COUNTRY_221C 2022-01-01   1.449425    1.371538          True
# 731   BRAND_2B96_COUNTRY_3AD0 2022-10-01   1.474142    1.344996          True
# 732   BRAND_2B96_COUNTRY_907E 2022-05-01   2.194711    1.952550          True
# 733   BRAND_2B96_COUNTRY_907E 2022-06-01   1.980363    1.888133          True
# 712   BRAND_2B96_COUNTRY_9488 2022-06-01   1.349114    1.196040          True
# 710   BRAND_2B96_COUNTRY_9488 2022-12-01   2.260419    1.204045          True
# 734   BRAND_2B96_COUNTRY_9891 2022-08-01   1.359310    1.518245          True
# 735   BRAND_2B96_COUNTRY_9891 2022-10-01   1.378953    1.632718          True
# 736   BRAND_2B96_COUNTRY_A67D 2022-04-01   1.084708    1.140083          True
# 737   BRAND_2B96_COUNTRY_A67D 2022-05-01   1.096195    1.155953          True
# 738   BRAND_2B96_COUNTRY_A67D 2022-07-01   1.118641    1.267055          True
# 739   BRAND_2B96_COUNTRY_D8B0 2022-04-01   4.340648    3.482528          True
# 740   BRAND_2B96_COUNTRY_D8B0 2022-05-01   4.430169    3.489050          True
# 741   BRAND_2B96_COUNTRY_EA71 2022-02-01   1.128015    1.177847          True
# 1530  BRAND_37FE_COUNTRY_0309 2022-04-01   1.461302    1.472060          True
# 1531  BRAND_37FE_COUNTRY_0309 2022-04-01   1.461302    1.448959          True
# 1532  BRAND_37FE_COUNTRY_4242 2022-09-01   1.202041    1.177551          True
# 1529  BRAND_37FE_COUNTRY_4253 2022-08-01   1.098367    1.040031          True
# 1528  BRAND_37FE_COUNTRY_4253 2022-12-01   1.107209    1.050759          True
# 1533  BRAND_37FE_COUNTRY_6B71 2022-02-01   1.096274    1.091761          True
# 1534  BRAND_37FE_COUNTRY_6B71 2022-04-01   1.101411    1.088746          True
# 1535  BRAND_37FE_COUNTRY_6B71 2022-08-01   1.103453    1.078064          True
# 1536  BRAND_37FE_COUNTRY_6C16 2022-08-01   1.282379    1.272983          True
# 1537  BRAND_37FE_COUNTRY_6C16 2022-08-01   1.282379    1.293348          True
# 1538  BRAND_37FE_COUNTRY_6C16 2022-10-01   1.326340    1.324841          True
# 1539  BRAND_37FE_COUNTRY_6F78 2022-09-01   1.107231    1.107479          True
# 1540  BRAND_37FE_COUNTRY_88A3 2022-07-01   1.022538    1.027375          True
# 1541  BRAND_37FE_COUNTRY_88A3 2022-08-01   1.034569    1.031426          True
# 1542  BRAND_37FE_COUNTRY_89F9 2022-08-01   3.476298    2.731721          True
# 1543  BRAND_37FE_COUNTRY_89F9 2022-08-01   3.476298    2.713648          True
# 1544  BRAND_37FE_COUNTRY_8DBB 2022-05-01   1.043850    1.080214          True
# 1545  BRAND_37FE_COUNTRY_907E 2022-02-01   1.370653    1.424196          True
# 1546  BRAND_37FE_COUNTRY_907E 2022-06-01   1.496196    1.469287          True
# 1547  BRAND_37FE_COUNTRY_9891 2022-04-01   1.223326    1.267059          True
# 1548  BRAND_37FE_COUNTRY_C8F4 2022-12-01   1.149825    1.128866          True
# 1549  BRAND_37FE_COUNTRY_D5B9 2022-04-01   1.119158    1.113224          True
# 1550  BRAND_37FE_COUNTRY_D5B9 2022-10-01   1.156589    1.110243          True
# 1551  BRAND_37FE_COUNTRY_D5B9 2022-12-01   1.181578    1.129266          True
# 1604  BRAND_387C_COUNTRY_445D 2022-05-01   1.018142    1.022017          True
# 1605  BRAND_387C_COUNTRY_4D48 2022-02-01   1.029470    1.029505          True
# 1885  BRAND_3938_COUNTRY_D8B0 2022-05-01   1.101827    1.036635          True
# 1884  BRAND_3938_COUNTRY_D8B0 2022-11-01   1.117976    1.036635          True
# 691   BRAND_39B3_COUNTRY_0C7D 2022-10-01   1.187734    1.152931          True
# 692   BRAND_39B3_COUNTRY_1007 2022-03-01   1.170436    1.161862          True
# 693   BRAND_39B3_COUNTRY_3AD0 2022-05-01   1.019775    1.019945          True
# 694   BRAND_39B3_COUNTRY_3AD0 2022-07-01   1.018455    1.022241          True
# 695   BRAND_39B3_COUNTRY_3AD0 2022-10-01   1.017668    1.020183          True
# 696   BRAND_39B3_COUNTRY_88A3 2022-05-01   1.020331    1.022685          True
# 697   BRAND_39B3_COUNTRY_FA79 2022-02-01   1.041801    1.045919          True
# 1154  BRAND_FD0B_COUNTRY_445D 2022-08-01   1.041215    1.034728          True
# 1155  BRAND_FD0B_COUNTRY_445D 2022-09-01   1.036172    1.047504          True
# 93    BRAND_FE66_COUNTRY_53A5 2022-02-01   1.018663    1.024163          True
# 94    BRAND_FE66_COUNTRY_53A5 2022-04-01   1.027430    1.024163          True
# 95    BRAND_FE66_COUNTRY_53A5 2022-05-01   1.017724    1.024163          True
# 96    BRAND_FE66_COUNTRY_53A5 2022-12-01   1.021957    1.024163          True
# 97    BRAND_FE66_COUNTRY_D8B0 2022-03-01   1.011965    1.024163          True
# 98    BRAND_FE66_COUNTRY_D8B0 2022-07-01   1.013582    1.024163          True
# 99    BRAND_FE66_COUNTRY_D8B0 2022-07-01   1.013582    1.024163          True
# 100   BRAND_FE66_COUNTRY_D8B0 2022-09-01   1.010142    1.024163          True
# 604   BRAND_FEAA_COUNTRY_0309 2022-01-01   1.274689    1.309948          True
# 605   BRAND_FEAA_COUNTRY_0309 2022-03-01   1.313972    1.328245          True
# 606   BRAND_FEAA_COUNTRY_0309 2022-11-01   1.472888    1.353779          True
# 607   BRAND_FEAA_COUNTRY_1007 2022-01-01   1.519181    1.482907          True
# 608   BRAND_FEAA_COUNTRY_4253 2022-10-01   1.157225    1.113008          True
# 609   BRAND_FEAA_COUNTRY_907E 2022-05-01   1.190094    1.240077          True
# 610   BRAND_FEAA_COUNTRY_907E 2022-12-01   1.193043    1.281040          True
# 611   BRAND_FEAA_COUNTRY_907E 2022-12-01   1.193043    1.317761          True
# 612   BRAND_FEAA_COUNTRY_9891 2022-01-01   1.049731    1.057990          True
# 613   BRAND_FEAA_COUNTRY_9891 2022-02-01   1.045775    1.053778          True
# 603   BRAND_FEAA_COUNTRY_B6AE 2022-09-01   1.007831    1.041817          True
# recent
#                    cluster_nl       date    target  prediction  zero_actuals
# 254   BRAND_014B_COUNTRY_6C16 2022-05-01  1.167239    1.005051         False
# 1317  BRAND_056A_COUNTRY_3AD0 2022-10-01  1.071099    1.143855         False
# 1323  BRAND_056A_COUNTRY_3AD0 2022-10-01  1.071099    1.143855         False
# 1331  BRAND_056A_COUNTRY_3AD0 2022-10-01  1.071099    1.143855         False
# 1335  BRAND_056A_COUNTRY_3AD0 2022-11-01  1.096515    1.129333         False
# 1330  BRAND_056A_COUNTRY_4442 2022-09-01  1.046044    1.066501         False
# 1325  BRAND_056A_COUNTRY_458E 2022-07-01  1.000000    1.036064         False
# 1327  BRAND_056A_COUNTRY_458E 2022-07-01  1.000000    1.036064         False
# 1333  BRAND_056A_COUNTRY_458E 2022-11-01  1.003344    1.039583         False
# 1334  BRAND_056A_COUNTRY_458E 2022-11-01  1.003344    1.039583         False
# 1316  BRAND_056A_COUNTRY_458E 2022-12-01  1.001433    1.046769         False
# 1332  BRAND_056A_COUNTRY_53A5 2022-08-01  1.223871    1.473317         False
# 1318  BRAND_056A_COUNTRY_53A5 2022-09-01  1.385883    3.303824         False
# 1321  BRAND_056A_COUNTRY_53A5 2022-11-01  1.672595    3.130803         False
# yearly_error : 0.022360337490383506, monthly_error: 0.02554593268138143
# yearly_error : 0.021643040149513418, monthly_error: 0.024137398278783848
# part1: 0.0014371881051529493, part2: 0.021516806061299715
# Performance: 0.02295399

# %% [markdown]
# # results

# %%
# Performance: 0.02934487
# EXPERIMENTS RESULTS

# ------------BASELINE----------------
# test set 0  - 6 minutes to run
# zeros_weight:  0.9355, recent_weight: 0.0645
# yearly_error : 0.03693342164842836, monthly_error: 0.03442995945710092
# yearly_error : 0.027495405951616664, monthly_error: 0.03058615500892749
# part1: 0.0023014690406533193, part2: 0.02716765013929453
# Performance: 0.02946912

#test set 1  - 6 minutes to run
# zeros_weight:  0.9295, recent_weight: 0.07050000000000001
# yearly_error : 0.04268486088274496, monthly_error: 0.03824872363441356
# yearly_error : 0.026760744740338675, monthly_error: 0.029631399856907083
# part1: 0.002852908854229838, part2: 0.026208249201569965
# Performance: 0.02906116

#test set 2  - 8 minutes to run
# zeros_weight:  0.94, recent_weight: 0.06000000000000005
# yearly_error : 0.03356011748782471, monthly_error: 0.0349476169409979
# yearly_error : 0.02713112040504676, monthly_error: 0.02876025829323739
# part1: 0.00205523203286468, part2: 0.02626894798819355
# Performance: 0.02832418

#-----------KNN  DRUG + COUNTRY----------------

# test set 0  - 19 minutes to run
# zeros_weight:  0.9355, recent_weight: 0.0645
# yearly_error : 0.09169320173510015, monthly_error: 0.08095651228337708
# yearly_error : 0.027662763535215323, monthly_error: 0.030642987211395873
# part1: 0.005567953277095891, part2: 0.027272514911727386
# Performance: 0.03284047

# test set 1  - 25 minutes to run
# zeros_weight:  0.9295, recent_weight: 0.07050000000000001
# yearly_error : 0.09136579680679932, monthly_error: 0.0801077890849526
# yearly_error : 0.027048458185710663, monthly_error: 0.029828876318610222
# part1: 0.006044443902684256, part2: 0.02643374121088313
# Performance: 0.03247819

#test set 2  - 18 minutes to run 
# zeros_weight:  0.94, recent_weight: 0.06000000000000005
# yearly_error : 0.09566592861899913, monthly_error: 0.08507456146890648
# yearly_error : 0.02713112040504676, monthly_error: 0.02903959436292604
# part1: 0.005422214702637173, part2: 0.026400235940947214
# Performance: 0.03182245

#-----------ONLY COUNTRY---------------- 
# test set 1  - 25 minutes to run
# zeros_weight:  0.9295, recent_weight: 0.07050000000000001
# yearly_error : 0.07845991954373274, monthly_error: 0.08290072217408267
# yearly_error : 0.026891157828794556, monthly_error: 0.029775082941053486
# part1: 0.005687962620552994, part2: 0.026335635397786876
# Performance: 0.0320236

#----------- ONLY COUNTRY TOP 4---------------- 
# test set 1  - 21 minutes to run
# zeros_weight:  0.9295, recent_weight: 0.07050000000000001
# yearly_error : 0.07915806380979566, monthly_error: 0.0568585339297157
# yearly_error : 0.02650190457425059, monthly_error: 0.029111600895537347
# part1: 0.0047945850703177756, part2: 0.025846376667083944
# Performance: 0.03064096

#---------DRUG ID TOP 2/4----------------
# test set 1  - 
# zeros_weight:  0.9295, recent_weight: 0.07050000000000001
# yearly_error : 0.07732206214645955, monthly_error: 0.04736550953716392
# yearly_error : 0.026199185581792767, monthly_error: 0.029088606263435644
# part1: 0.004395236901847728, part2: 0.025695001260069905
# Performance: 0.03009024

#---------DRUG_ID  KNN WITH LOG TARGET----------------
# test set 1  - 
# zeros_weight:  0.9295, recent_weight: 0.07050000000000001
# yearly_error : 0.06274796181076821, monthly_error: 0.04580291921099955
# yearly_error : 0.02199014588758101, monthly_error: 0.025727597386198515
# part1: 0.0038264185560173136, part2: 0.022176821186489035
# Performance: 0.02600324

#---------DRUG_ID WITH LOG TARGET GRID SEARCH LIGHTGBM----------------
# test set 1  - 
# zeros_weight:  0.9295, recent_weight: 0.07050000000000001
# yearly_error : 0.03126266390525447, monthly_error: 0.030690032635825506
# yearly_error : 0.021905372531847083, monthly_error: 0.024818301190838978
# part1: 0.0021838325530730692, part2: 0.021714827362618344
# Performance: 0.02389866

#---------DRUG_ID WITH LOG TARGET GRID SEARCH LIGHTGBM----------------
# test set 1  - 
# zeros_weight:  0.9295, recent_weight: 0.07050000000000001
# yearly_error : 0.03126266390525447, monthly_error: 0.030690032635825506
# yearly_error : 0.021905372531847083, monthly_error: 0.024818301190838978
# part1: 0.0021838325530730692, part2: 0.021714827362618344
# Performance: 0.02389866

#---------DRUG_ID 20, COUNTRY 15 WITH LOG TARGET NORMAL LIGHTGBM----------------
# test set 1  - 7 MINS
# zeros_weight:  0.9295, recent_weight: 0.07050000000000001
# yearly_error : 0.03126266390525447, monthly_error: 0.030690032635825506
# yearly_error : 0.02162793188877339, monthly_error: 0.023606944439469948
# part1: 0.0021838325530730692, part2: 0.021022908773551095
# Performance: 0.02320674

#---------DRUG_ID 5, COUNTRY KNN 13 WITH LOG TARGET NORMAL LIGHTGBM----------------
# test set 1  - 2 MINS
# zeros_weight:  0.9295, recent_weight: 0.07050000000000001
# yearly_error : 0.038231430812556866, monthly_error: 0.035628223427350524
# yearly_error : 0.021694837899392846, monthly_error: 0.023535560386310755
# part1: 0.002603552811956736, part2: 0.02102082760328075
# Performance: 0.02362438

#---------DRUG_ID 20, COUNTRY 15 WITH LOG TARGET NORMAL LIGHTGBM----------------
# test set 1  - 7 MINS
# zeros_weight:  0.9295, recent_weight: 0.07050000000000001
# yearly_error : 0.03126266390525447, monthly_error: 0.030690032635825506
# yearly_error : 0.02162793188877339, monthly_error: 0.023606944439469948
# part1: 0.0021838325530730692, part2: 0.021022908773551095
# Performance: 0.02320674


#---------DRUG_ID 20, COUNTRY 15 WITH LOG TARGET NORMAL LIGHTGBM----------------
# test set 0  - 7 MINS
# zeros_weight:  0.9355, recent_weight: 0.0645
# yearly_error : 0.02489168386193652, monthly_error: 0.02585101835474924
# yearly_error : 0.021672824007509073, monthly_error: 0.024304988849832124
# part1: 0.0016364521464881157, part2: 0.021506121964021345
# Performance: 0.02314257


#---------DRUG_ID 20, COUNTRY 15 WITH LOG TARGET NORMAL LIGHTGBM----------------
# test set 1  - 7 MINS
# zeros_weight:  0.9295, recent_weight: 0.07050000000000001
# yearly_error : 0.03126266390525447, monthly_error: 0.030690032635825506
# yearly_error : 0.02162793188877339, monthly_error: 0.023606944439469948
# part1: 0.0021838325530730692, part2: 0.021022908773551095
# Performance: 0.02320674

#---------DRUG_ID 20, COUNTRY 15 WITH LOG TARGET NORMAL LIGHTGBM----------------
# test set 2  - 7 MINS
# zeros_weight:  0.94, recent_weight: 0.06000000000000005
# yearly_error : 0.022360337490383506, monthly_error: 0.02554593268138143
# yearly_error : 0.021643040149513418, monthly_error: 0.024137398278783848
# part1: 0.0014371881051529493, part2: 0.021516806061299715
# Performance: 0.02295399

# %%
# check if knn data and dummy data are same
# make groups for each historical data and increase the lags respectively for each of them groups
# run models and hypertune them?
# run knn or cosine similarity for the data

# %%
#changes made 
#knn country 4 and drug 5 - works
#made the knn with median aggregation - works
#log transform target - works good
# outlier removal - useless
#remove 2020 - useless
#made country 15 and drug 20
